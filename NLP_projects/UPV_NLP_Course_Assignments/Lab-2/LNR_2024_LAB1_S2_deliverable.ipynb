# %% [markdown]
# <h1 align="center">LAB1S2. Preprocessing and Traditional
# Language Representation using scikit-learn
# tools</h1>
#
# <h3 style="display:block; margin-top:5px;" align="center">Natural Language and Information Retrieval</h3>
# <h3 style="display:block; margin-top:5px;" align="center">Degree in Data Science</h3>
# <h3 style="display:block; margin-top:5px;" align="center">2024-2025</h3>
# <h3 style="display:block; margin-top:5px;" align="center">ETSInf. Universitat Politècnica de València</h3>
# <br>

# %% [markdown]
# ### Put your names here
#
# - (replace with one name)
# - (replace with another name)

# %%
# IF YOU USE GOOGLE COLAB AND WANT READ A FILE
#from google.colab import drive
#drive.mount('/content/drive')

# %% [markdown]
# ## Some help, if you need it

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.decomposition import TruncatedSVD
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import re

definition = {
    "a": "Bag of Words (binary)",
    "b": "Bag of Words (Term-Frequency) without normalization",
    "c": "Bigrams of Words (Term-Frequency) without normalization",
    "d": "Trigram of Characters (Term-Frequency) without normalization",
    "e": "TF-IDF based on words with 'l2' normalization",
    "f": "LSA based on TF-IDF of words (50 singular values)",
    "g": "LSA based on TF-IDF of words (100 singular values)"
}
# !pip install pandas

# %% [markdown]
# ## Load de dataset

# %%
filename = "EXIST2024_EN_examples.csv"

# COMPLETE

# %% [markdown]
# ## Preprocess dataset

# %%
import re

web_re = re.compile(r"https?:\/\/[^\s]+", re.U)

def preprocess(text):
    # COMPLETE
    pass

# COMPLETE

# %% [markdown]
# ## Create the vectorizers and compute the representation of the tweets

# %%
# COMPLETE
# Out:
# a (14327,)
# b (14327,)
# c (51566,)
# d (17276,)
# e (14327,)
# f (50,)
# g (100,)

# %% [markdown]
# ## Compute cosine similarities

# %%
# COMPLETE

# %% [markdown]
# ## Show results

# %%
# COMPLETE
# Out:
# Bag of Words (binary)
# =====================
#
# label: NO
# sentence1: "♫ now playing : treat her like a lady (single version) by the temptations  "
# --------------------
# sentence2: "now playing:  the temptations - treat her like a lady   listen live: "
# distance: 0.7628
#
#
# label: YES
# sentence1: "@yayroger @victoriarossi @ionaguyf @metsdaddy2013 @byandrewwagner @themikebpeters dr. cox, does this shade of red make me look like a clown?no barbie. it makes you look like a prostitute who caters exclusively to clowns."
# --------------------
# sentence2: "sharon: oh, loki, does this lipstick make me look like a clown?loki: no, barbie, no... it makes you look like a prostitute who caters exclusively *to* clowns."
# distance: 0.7126
#
#
# Bag of Words (Term-Frequency) without normalization
# ===================================================
#
# label: NO
# sentence1: "@bleedthisway replay free woman breebylon &gt;&gt;&gt; flop this way"
# --------------------
# sentence2: "replay&gt;alice&gt;babylon&gt;free woman "
# distance: 0.7778
#
#
# label: YES
# sentence1: "@yayroger @victoriarossi @ionaguyf @metsdaddy2013 @byandrewwagner @themikebpeters dr. cox, does this shade of red make me look like a clown?no barbie. it makes you look like a prostitute who caters exclusively to clowns."
# --------------------
# sentence2: "sharon: oh, loki, does this lipstick make me look like a clown?loki: no, barbie, no... it makes you look like a prostitute who caters exclusively *to* clowns."
# distance: 0.7247
#
#
# Bigrams of Words (Term-Frequency) without normalization
# =======================================================
#
# label: NO
# sentence1: "earth angel (androgynous mind) "
# --------------------
# sentence2: "average hacker fan vs average earth angel (androgynous mind) enthusiast"
# distance: 0.5774
#
#
# label: YES
# sentence1: "@yayroger @victoriarossi @ionaguyf @metsdaddy2013 @byandrewwagner @themikebpeters dr. cox, does this shade of red make me look like a clown?no barbie. it makes you look like a prostitute who caters exclusively to clowns."
# --------------------
# sentence2: "sharon: oh, loki, does this lipstick make me look like a clown?loki: no, barbie, no... it makes you look like a prostitute who caters exclusively *to* clowns."
# distance: 0.6124
#
#
# Trigram of Characters (Term-Frequency) without normalization
# ============================================================
#
# label: NO
# sentence1: "♫ now playing : treat her like a lady (single version) by the temptations  "
# --------------------
# sentence2: "now playing:  the temptations - treat her like a lady   listen live: "
# distance: 0.71
#
#
# label: YES
# sentence1: "@yayroger @victoriarossi @ionaguyf @metsdaddy2013 @byandrewwagner @themikebpeters dr. cox, does this shade of red make me look like a clown?no barbie. it makes you look like a prostitute who caters exclusively to clowns."
# --------------------
# sentence2: "sharon: oh, loki, does this lipstick make me look like a clown?loki: no, barbie, no... it makes you look like a prostitute who caters exclusively *to* clowns."
# distance: 0.666
#
#
# TF-IDF based on words with 'l2' normalization
# =============================================
#
# label: NO
# sentence1: "@bleedthisway replay free woman breebylon &gt;&gt;&gt; flop this way"
# --------------------
# sentence2: "replay&gt;alice&gt;babylon&gt;free woman "
# distance: 0.7324
#
#
# label: YES
# sentence1: "@yayroger @victoriarossi @ionaguyf @metsdaddy2013 @byandrewwagner @themikebpeters dr. cox, does this shade of red make me look like a clown?no barbie. it makes you look like a prostitute who caters exclusively to clowns."
# --------------------
# sentence2: "sharon: oh, loki, does this lipstick make me look like a clown?loki: no, barbie, no... it makes you look like a prostitute who caters exclusively *to* clowns."
# distance: 0.509
#
#
# LSA based on TF-IDF of words (50 singular values)
# =================================================
#
# label: NO
# sentence1: "@mainetrendteam @mainedcm androgynous (mind).mainexlazada 1111supershow#lazadaxmaine @mainedcm #maineforlazada1111 #mainemendoza @mainedcm"
# --------------------
# sentence2: "earth angel (androgynous mind) "
# distance: 0.9915
#
#
# label: YES
# sentence1: "@twinklybunny perfect young body. i would like to fuck you."
# --------------------
# sentence2: "@misskatie2021 i would like to fuck you 😂😂😂à french fan"
# distance: 0.9918
#
#
# LSA based on TF-IDF of words (100 singular values)
# ==================================================
#
# label: NO
# sentence1: "@mainetrendteam @mainedcm androgynous (mind).mainexlazada 1111supershow#lazadaxmaine @mainedcm #maineforlazada1111 #mainemendoza @mainedcm"
# --------------------
# sentence2: "earth angel (androgynous mind) "
# distance: 0.9973
#
#
# label: YES
# sentence1: "@twinklybunny perfect young body. i would like to fuck you."
# --------------------
# sentence2: "@misskatie2021 i would like to fuck you 😂😂😂à french fan"
# distance: 0.9784
