# %% [markdown]
# <h1 align="center">Lab 2:  Sexism Identification in Twitter</h1>
# <h2 align="center">Session 4. Transformers and Explainability</h2>
# <h3 style="display:block; margin-top:5px;" align="center">Natural Language and Information Retrieval</h3>
# <h3 style="display:block; margin-top:5px;" align="center">Degree in Data Science</h3>
# <h3 style="display:block; margin-top:5px;" align="center">2024-2025</h3>
# <h3 style="display:block; margin-top:5px;" align="center">ETSInf. Universitat Politècnica de València</h3>
# <br>

# %% [markdown]
# ### Put your names here
#
# - (replace with one name)
# - (replace with another name)

# %% [markdown]
# ### CONSTANTS

# %%
COLAB = False # IF YOU USE GOOGLE COLAB -> COLAB = True
PIP = False # IF YOU NEED INSTALL LIBRARIES -> PIP = True

# %% [markdown]
# **If you have trouble installing ferret-xai or jsonnet on Linux, try installing these packages first:**
#
# - sudo apt install cmake
# - sudo apt install g++
# - sudo apt install make
#
# **Or that after installing ferret-xai:**
#
# - conda install -c conda-forge libstdcxx-ng --update-deps

# %% [markdown]
# ## Some libraries

# %%
if PIP:
    # !pip install transformers --upgrade
    # !pip  install datasets accelerate --upgrade
    # !pip install ferret-xai --upgrade
    # !pip install tqdm

# %%
import os
import sys
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
from transformers import AutoTokenizer, AutoModelForSequenceClassification, Trainer, TrainingArguments
from sklearn.metrics import precision_recall_fscore_support, confusion_matrix, classification_report, accuracy_score
from sklearn.preprocessing import LabelEncoder
import pandas as pd
from typing import List, Tuple
import tqdm

# %% [markdown]
# ## Import readerEXIST2025 library, and read the dataset

# %%
if COLAB is True:
  from google.colab import drive
  drive.mount('/content/drive')
  base_path = "/content/drive/MyDrive/LNR/"
else:
  base_path = "../"

# %%
library_path = os.path.join(base_path, "Lab2-S1")
sys.path.append(library_path)
from readerEXIST2025 import EXISTReader

# %%
# path to the dataset, adapt this path wherever you have the dataset
dataset_path = os.path.join(base_path, "../corpora/EXIST_2025_Dataset_V0.2/")

file_train = os.path.join(dataset_path, "EXIST2025_training.json")
file_dev = os.path.join(dataset_path, "EXIST2025_dev.json")

reader_train = EXISTReader(file_train)
reader_dev = EXISTReader(file_dev)

EnTrainTask1, EnDevTask1 = reader_train.get(lang="EN", subtask="1"), reader_dev.get(lang="EN", subtask="1")
SpTrainTask1, SpDevTask1 = reader_train.get(lang="ES", subtask="1"), reader_dev.get(lang="ES", subtask="1")

# %% [markdown]
# ## Dataset class

# %%
class SexismDataset(Dataset):
    def __init__(self, texts, labels, ids, tokenizer, max_len=128, pad="max_length", trunc=True,rt='pt'):
        self.texts = texts.tolist()
        self.labels = labels
        self.ids = ids
        self.tokenizer = tokenizer
        self.max_len = max_len
        self.pad = pad
        self.trunc = trunc
        self.rt = rt

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = str(self.texts[idx])
        inputs = self.tokenizer.encode_plus(
            text,
            add_special_tokens=True,
            max_length=self.max_len,padding=self.pad, truncation=self.trunc,
            return_tensors=self.rt
        )

        return {
            'input_ids': inputs['input_ids'].flatten(),
            'attention_mask': inputs['attention_mask'].flatten(),
            'labels': torch.tensor(self.labels[idx], dtype=torch.long),
            'id': torch.tensor(self.ids[idx], dtype=torch.long)
        }

# %% [markdown]
# ## Auxiliary functions

# %%
from collections import Counter # Counter counts the number of occurrences of each item
from itertools import tee, count

def uniquify(seq, suffs = count(1)):
    """Make all the items unique by adding a suffix (1, 2, etc).

    `seq` is mutable sequence of strings.
    `suffs` is an optional alternative suffix iterable.
    """
    not_unique = [k for k,v in Counter(seq).items() if v > 1] # so we have: ['name', 'zip']
    # suffix generator dict - e.g., {'name': <my_gen>, 'zip': <my_gen>}
    suff_gens = dict(zip(not_unique, tee(suffs, len(not_unique))))
    for idx,s in enumerate(seq):
        try:
            suffix = str(next(suff_gens[s]))
        except KeyError:
            # s was unique
            continue
        else:
            seq[idx] += suffix

def deduplicate(explanations):
    for i in range(len(explanations)):
        tokens = explanations[i].tokens
        uniquify(tokens, (f'_{x!s}' for x in range(1, 100)))
        explanations[i].tokens=tokens
    return explanations

# %% [markdown]
# # Two options to predict

# %% [markdown]
# ### The simplest

# %%
def predict_op1(model, dataset, args = {}):

    # Set up the Trainer, yes, a trainer for prediction!
    training_args = TrainingArguments(
        output_dir="./output",
        per_device_eval_batch_size = args.get("per_device_eval_batch_size", 16),
        do_train=False,
        do_eval=False,
    )
    trainer = Trainer(model=model, args=training_args)

    # Predict
    predictions = trainer.predict(val_dataset)

    # Get logits, shape = #samples, num_classes (2)
    logits = predictions.predictions
    
    # Compute probability with softmax, requires logits to be tensors (unnecessary to compute the class)
    probs = torch.nn.functional.softmax(torch.tensor(logits), dim=-1).numpy()    

    # Get the predicted class using argmax
    pred_classes = np.argmax(logits, axis=-1)
    # equals to: pred_classes = np.argmax(probs, axis=-1)


    # COMPLETE TO ALSO RETURN THE PROBABILITY OF THE PREDICTED CLASS

    
    return pred_classes

# %% [markdown]
# ### The coolest, if you know what you're doing

# %%
#EnTrainTask1, EnDevTask1 = reader_train.get(lang="EN", subtask="1"), reader_dev.get(lang="EN", subtask="1")
#SpTrainTask1, SpDevTask1

device = "cpu"
if torch.cuda.is_available():
    device = torch.device("cuda")
elif torch.backends.mps.is_available():
    device = torch.device("mps")

def predict_op2(model, dataset, args = {}):
    # batch_size
    batch_size = args.get("per_device_eval_batch_size", 16)
    
    model.to(device)
    # Set eval model, no gradient stored
    model.eval()
    
    # Prepare DataLoader
    dataloader = DataLoader(dataset, batch_size=batch_size)
    
    # Prediction loop
    logits_list = []
    with torch.no_grad():
        for batch in tqdm.notebook.tqdm(dataloader):
            del batch["id"]
            batch = {k: v.to(device) for k, v in batch.items()}
            # equals to: outputs = model.forward(**batch)
            outputs = model(**batch)
            logits_list.append(outputs.logits)

    # Concatenate and move logits to the CPU, shape = #samples, num_classes (2)
    logits = torch.cat(logits_list, dim=0).cpu()

    # Compute probability with softmax, requires logits to be tensors (unnecessary to compute the class)
    probs = torch.nn.functional.softmax(logits, dim=-1).numpy()
    
    # Get the predicted class using argmax
    pred_classes = np.argmax(logits, axis=-1).numpy()
    # equals to: pred_classes = np.argmax(probs, axis=-1).numpy()

    
    # COMPLETE TO ALSO RETURN THE PROBABILITY OF THE PREDICTED CLASS
    
    return pred_classes

# %% [markdown]
# ### Predictions from the best Spanish model

# %%
# COMPLETE
model_name = "" # path to your best Spanish model
base_model = "" # the name model your best model is based on. It is necessary if your model doesn't include a tokenizer


tokenizer = AutoTokenizer.from_pretrained(base_model)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

val_dataset = SexismDataset(SpDevTask1[1], LabelEncoder().fit_transform(SpDevTask1[2]), [int(x) for x in SpDevTask1[0]], tokenizer)

preds, probs = predict_op1(model, val_dataset)

# If you want to verify that both options do the same, try this:
#y_pred1, _ = predict_op1(model, val_dataset)
#y_pred2, _ = predict_op2(model, val_dataset)
#all(x1 == x2 for x1, x2 in zip(y_pred1, y_pred2))

# %% [markdown]
# ### Evaluation of the results

# %%
def compute_metrics(y_true, y_pred):
    precision, recall, f1, _ = precision_recall_fscore_support(
        y_true, y_pred, average='binary'
    )
    acc = accuracy_score(y_true, y_pred)
    return {
        'accuracy': acc,
        'f1': f1,
        'precision': precision,
        'recall': recall,
    }

# Metrics
metrics = compute_metrics(val_dataset.labels, preds)
print("Metrics:", metrics)

# Confusion matrix
conf_matrix = confusion_matrix(val_dataset.labels, preds)#, labels=["NO", "YES"])
print("\nConfusion matrix:")
print(conf_matrix)

# Classification report
class_report = classification_report(val_dataset.labels, preds, target_names=["NO", "YES"], digits=4)
print("\nReport:")
print(class_report)
# Out:
# Metrics: {'accuracy': 0.8673469387755102, 'f1': 0.8717948717948718, 'precision': 0.8983739837398373, 'recall': 0.8467432950191571}
#
# Confusion matrix:
# [[204  25]
#  [ 40 221]]
#
# Report:
#               precision    recall  f1-score   support
#
#           NO     0.8361    0.8908    0.8626       229
#          YES     0.8984    0.8467    0.8718       261
#
#     accuracy                         0.8673       490
#    macro avg     0.8672    0.8688    0.8672       490
# weighted avg     0.8693    0.8673    0.8675       490

# %% [markdown]
# ### Plot confusion matrix

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", cbar=False,
            xticklabels=["No", "Yes"],
            yticklabels=["No", "Yes"])
plt.title("Confusion Matrix")
plt.xlabel("Prediction")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# ### Text and probability of False positive and False negative

# %%
def false_positive_false_negative(
    y_true: List[int], y_pred: List[int], pred_probs: List[float], texts: List[str]
) -> Tuple[List[Tuple[float, str]], List[Tuple[float, str]]]:
    """
    returns incorrect predictions from a binary classification model.

    Parameters:
    - y_true (list[int]): True labels for each sample (0 or 1).
    - y_pred (list[int]): Labels predicted by the model (0 or 1).
    - pred_probs (list[float]): Probabilities assigned by the model to the predicted class.
    - texts (list[str]): Text of each sample.

    Returns:
    - false_positives (list[tuple[float, str]]): List of tuples for false positives.
    - false_negatives (list[tuple[float, str]]): List of tuples for false negatives.
    Each tuple of both lists includes the probability and the text of the sample.
    """

    false_positive = []
    false_negative = []
    
    # COMPLETE!!!
    
    return false_positive, false_negative

# %%
fpositive, fnegative = false_positive_false_negative(y_true = val_dataset.labels, y_pred = preds, pred_probs = probs, texts = val_dataset.texts)

print("False positive:", len(fpositive))
for s in fpositive:
    print('**', s)

print("\n\nFalse negative:", len(fnegative))
for s in fnegative:
    print('**', s)
# Out:
# False positive: 25
# ** (0.97861713, 'Adoro las fotos pero están usando mal el término, el manspreading no es solo sentarse con las piernas abiertas. :/ https://t.co/EMrpmRrSdD')
# ** (0.9749672, '@PSOE @Adrilastra La prostitución forzada, el proxenetismo, el rufianismo, la trata o como queráis llamarlo, ya está contemplado en el Código Penal como delito. Lo que no se debe ilegalizar, sea o no moralmente reprochable, es que una persona disponga de su cuerpo libremente.')
# ** (0.97452116, 'Nos roban a manos llenas. Sólo les falta violar a tus familiares y sodomizar s tus hijos.')
# ** (0.97444034, '@IreneMontero @IreneMontero, efectivamente.. las mujeres no deben de ser discriminadas salarialmente por pertenecer a cuerpos policiales de otras comunidades, localidades, etc.')
# ** (0.9739942, '@Cristina_Coach @Dillita1 @lapropriaWinter @Alex_con_3X ¿Usted acaso vio a Ruiz Cortines saliendo a militar con movimientos feministas? Promulgó una ley que amparó un derecho para las mujeres, no era ningún feminista. Una cosa no tiene nada que ver con la otra. Usted es quien no entiende que el feminismo es un movimiento político.')
# ** (0.96237886, '@Not_TsundereZ CalvoAh diablos no me denuncies por acoso sexual 😭😭Pero fuera bromas, que tiene que ver una cosa con la otra yo tampoco entiendo nada tiene sentido https://t.co/W2ErmEVqQt')
# ** (0.95066637, '@musta_lou @la7loua muy contenta de que no hicieras manspreading en el cabify para que pudiera sentarme en condiciones 😚')
# ** (0.9455689, '@nabellalucia No joda yo tengo como 5 mejores amigas y de pana nunca nos hemos comido. Ella son sabiduría pura para entender a las mujeres, nos enseñan trucos para conquistar y evitar peos.')
# ** (0.9071533, '@clitfreaks @Andres54167596 Soy muy cortado aunque me gusta masturbarme viendo como se follan por el culo todavia soy virgen me gustaria follar a un pasivo gracias')
# ** (0.88573545, '#Feminismo#VindicamosPara ver más sobre la Historia de las Mujeres:https://t.co/XwfmTmrCp6')
# ** (0.8552819, '@Causa1936 Pues un crack la chica, eso sí  es una mujer empoderada: a las bravas y contracorriente')
# ** (0.8530221, 'Agarré un desodorante sin querer que se llama Patrichs y pensé que decía Patriarchy jajsjsj olor a VARON')
# ** (0.82781297, 'Os confieso q cada vez q veo una foto de orslok 2015 se me caen las bragas')
# ** (0.8220233, 'La gente que come el chicle con la boca abierta? 🥴 Amiga, pareces una puta vaca pastando. Iiiiiiuuuuuu😷')
# ** (0.78565794, 'Hoy en clases una chica se quejó con la profesora porque vino a dar el parcial sin dormir y que seguro le fue mal por eso.  Les juro que me empecé a cagar de risa atrás Mamita....lo que te espera')
# ** (0.7834932, '@Emanuelrodguez Que no somos animales para reproducirnos sin consciencia, dejando vástagos por el mundo sin preocuparnos de lo que han de vestir, comer y recibir como educación. Una "sobrepoblación" de un hogar espiritual y materialmente inadecuado puede ser causa de males como el abuso sexual.')
# ** (0.69910574, '@soyyokarim11 @Joeluscommunis Lelos como tú que se piensan que los dibujos animados de hace 40 años están hechos para promocionar estereotipos de género')
# ** (0.6940862, '@QuiqueGodoy Jajajajaja Cínico de pacotilla. Vos y tu familia se han hartado del hueveo al erario por generaciones y ahora salís haciéndote el virgencito.')
# ** (0.6478557, 'chacha un mes ignorándome y ahora me vai a felicitar cómo si nada? 🖕🏼')
# ** (0.6395189, 'La jornada intensiva en los colegios perjudica a los alumnos y agrava la brecha de género https://t.co/9fV5fxcZEm a través de @La_SER')
# ** (0.63375306, '@Sassizavala Sassi una hermosura de mujer,saludame soy tu fan ☺')
# ** (0.61464214, 'Si usted está pensando en votar r3chazo, le recuedo que Cecila Morel, ex primera dama, le da miedito que se deje de abusar del pueblo, por que ella dijo...“Vamos a tener que disminuir nuestros privilegios y compartir con los demás”...con que dejen de robar ya estariamos!')
# ** (0.571713, '@ParticipaH no no es si solo es cuando no te apegas a los estereotipos de género')
# ** (0.56903666, 'Personas con capacidad de menstruar,  incluye tanto a mujeres (personas de sexo biológico femenino, como de igual identidad de género), y a personas trans o no binarias. Personas que nacen con una base biológica femenina, pero que su identidad de género no condice con su sexo.')
# ** (0.5172075, 'Como será el estado de mi papá que llego y le dijo a mi mamá -Gorda sos el amor de mi vida Na si yo los amo JAJAJAJ')
#
#
# False negative: 40
# ** (0.98269296, '@RaulZamudioraul Los cómicos amenazaron que esta semana iba El Especial del Humor, Risas y Salsa y además el Chavo , pero nunca dijeron que también iba la Serie Rosa, con el capítulo Violacion sin Resistencia!! Buajajajajjaja')
# ** (0.9604234, 'En #CLM trabajamos cada día para romper el ‘glass celling’. También en el medio rural donde existe una doble discriminación. Por eso nuestra Ley del Estatuto de las Mujeres Rurales, pionera en España. Impulsando su #empoderamiento ✉️ Hoy, en #cartasaladirectora @elpais_espana https://t.co/pVUkhQ3a8F')
# ** (0.95421106, '@BalbontinCas @BalbontinCas Me arrepiento de haber contestado a su tuit. No porque simpatice con Vox. Si no por haber leído un tuit, donde se demuestra la falta de sensibilidad, y sentido común. Literal: Entre la baja maternal, la regla, la depresión posparto. Hilo')
# ** (0.9380825, 'Absuelto, si, pero, quién le devuelve su vida?. Cuanto daño el pvto    #YoSiTeCreo   @IreneMontero   @Adrilastra   #ComunismoEsMiseria   #presunciondeinocencia    #LaReunionSecreta https://t.co/wt5rSNo116')
# ** (0.92896664, 'Emakunde pide "plantar cara a la cultura de la violación" en las fiestas vía @gasteizhoy https://t.co/dQe2cFN6Qo')
# ** (0.9209795, 'No tengo palabras,horrible y x desgracia hay tantos padres así todavía hoy.Siempre he defendido los derechos d mi hija a una vida plena,incluso cuando no estaba d moda. “Mis padres me esterilizaron con 18 años mediante manipulaciones” https://t.co/UTJeyX6TkW vía @elsaltodiario')
# ** (0.91572213, '@MovCiudadanoNL El Fiscal Guerrero tiene razón,la @FiscaliaNL es la responsable de investigar los delitos feminicidio, desaparicion,etc.:y el gobernador @samuel_garcias es el responsable de garantizar q estos hechos NO sucedan,pues por mandato de ley es el responsable de nuestra seguridad.')
# ** (0.9133411, 'https://t.co/IBe7WFRhYqComo guionista de esta obra de arte quiero pediros a todos que lo veáis y me deis vuestra sincera opinión, menos la de Laura que es una niñata envidiosa que no ha dado un palo al agua en su vida')
# ** (0.8936922, 'ahora que me relaciono de una manera más libre y menos normativa sufro menos esas violencias sistemáticas del amor romántico, pero aún así sufro las secuelas de haber experimentado tanto abuso en el pasado')
# ** (0.87791145, '#EnVivo Conferencia "Barreras invisibles para madres trabajadoras", impartida por la Mtra. Virginia Shaday Gutiérrez León https://t.co/a0I792uYSb @diigeBUAP @BUAPoficial')
# ** (0.87294537, 'Conceptos del “experimento constitucional” de dudosa definición:🤡👀🫣- Igualdad sustantiva.- Empresas semipúblicas.- Grupos históricamente excluidos.- Enfoque de género.- Medidas afirmativas.- Criterio de proporcionalidad.- Democracia paritaria.- Maritorio.#rechazo')
# ** (0.86237216, 'Ando mas relajado que papá con hija fea por que no salgo en estos tik toks😮\u200d💨')
# ** (0.84797037, '@lorenmontalvo Depende si te refieres a identidad de género, sexo biológico ,o expresión de género. Fajese a estudiar antes de apoyar sectores que sólo escupen ignorancia.')
# ** (0.84444696, 'OKEY PERO CUANDO SUS OJOS SE PONEN ROJOS POR SU MAGIA NANANANA ES INCREÍBLE COMO WANDA SIMPLEMENTE EXISTE Y YO ELIJO SER SU PERRA https://t.co/SN4fE2odPc')
# ** (0.8424324, '@Sudameris000 Pero lo que quiero enfatizar es que esa parte del relato es más para los culposos palermitanos, y no para el grueso de votantes.Y que ya pasó de moda, de hecho, ahora están con el feminismo, el lenguaje inclusivo y todo eso. "La dictadura" ya pasó de moda.')
# ** (0.8075178, 'Si tu revolución no reconoce la interseccionalidad y el hecho de que la exclusión no ha sido uniforme sino que ha sido más profunda dependiendo de otros motivos como el género o color de piel no la quiero')
# ** (0.7707323, 'El lobo Carrasco si puede le come la polla a Messi a dos manos, que cansino')
# ** (0.74794775, 'Soy ingeniera civil y vengo con short, falda, jeans rotos y crop top a trabajar, y todo normal, no me queda mejor el diseño si vengo de traje https://t.co/gbnnZuyS3c')
# ** (0.7353963, 'traigo mucha rabia porque un señor en la calle me gritó algo y no le dije ni hice nada cuando perfectamente pude hacerlo, maldita sea')
# ** (0.7352587, '@carlosclavijo22 Se puede opinar de la ley que incentiva la contratación de hombres? Se llama discriminación indirecta. Quien hace esa ley tiene un desconocimiento total del mercado laboral.')
# ** (0.73161316, 'Es literalmente romantización de relaciones abusivas pero ahora en live action🤪🤪🤩🤩')
# ** (0.6962469, '@aspergeralos40 Entiendo tu situación y tu cabreo es comprensible totalmente, pero lo q dices no es discriminación positiva. Y sinceramente, veo complicado q eso q cuentas sea así al 100%. Soy mujer con discapacidad y he sufrido la doble discriminación toda mi vida.')
# ** (0.68498486, 'seguir idealizando y romantizando características sexo corporales adeptas al androcentrismo y a la masculinidad.')
# ** (0.67317665, 'Ojalá algún día llegue en dónde la vigorexia en los varones se haga tan viral al igual que los TCA restantes y el falocentrismo u.u')
# ** (0.6696298, '03.05.22Concéntrate con nosotros en memoria de Ouardia y por el fin de la violencia machistaEl jueves 5 de mayo a las 8 de la tarde en la puerta del ayuntamiento de San Miguel¡Da un paso adelante contra la violencia de género!')
# ** (0.65581703, '@PoliciaHorny posibles a los tuyos. Por eso megustaría que si podías pasarme unafoto de ellos sin sujetador ni nadapara enseñárselos al cirujano, y quequeden lo más parecidos posibles alos tuyos.Espero que puedasayudarla, un abrazo fuerte')
# ** (0.6509618, '👉🏼Corrección: La @UESoficial, pese que es una institución pública, no cuenta con Unidad de Género. La instancia a la que señalamos de inacción es el Centro de Estudios de Género.')
# ** (0.6509016, '@Charlypepa69 Ah claro que sí , igual y en una de esas me permiten invitarles unas frías para conocernos , pues ella me parece sumamente atractiva')
# ** (0.64053893, '@suzidane_ Si es culo anduviera contigo, probablemente no serías el único que se lo anduviera comiendo.')
# ** (0.62929875, 'Empoderamiento o hembrismo en los años 60s 🥴🥴 https://t.co/QBXeAxWXBz')
# ** (0.6061876, '@Horacio_Cartes Tampoco a nosotros ya no saben que decir ,la ciudadanía no es tonta ,el presidente al que usted le salvo se presta como dinero sencillo   como un idiota útil del vice presidente a decir mentiras, ya no tiene remedio presidente se va y se va como una señorita.Adelanteeeee!!')
# ** (0.5968308, 'Les encanta mamar de body positivity hasta que es alguien flacx. Dejen de opinar sobre el cuerpo de lxs demás🤫')
# ** (0.589614, '@antituco4ever @CesarAcunaP @UCV_Peru Termino de leer la cagada de la Asamblea Chilena. Nueva constitución pura mierda...   "Democracia paritaria. El Estado reconoce y promueve una sociedad en la que mujeres, hombres, diversidades y disidencias sexogenéricas participen en condiciones de igualdad sustantiva"')
# ** (0.5887048, '@radioconvos899 @pasaroncosas899 #miercolesdegrieta 100 % papel, los que usan libro electronico, seguro practican sexting, es decir, no la ponen nunca, aparte de que libro virtual me suena a cositorto.')
# ** (0.5800241, '@Bautiicapitani Uno te pregunta preocupado, y el culo parado no saluda por la calle. Mala persona')
# ** (0.5799189, 'Lanzamos #EquiRutas con el propósito de incrementar la participación de las mujeres en el sector laboral, vinculación en cargos de liderazgo y reducir la brecha salarial de género. 👩🏽\u200d💼👩🏽\u200d💻¡Únete con tu organización a esta #IPG! ➡️ https://t.co/wSH7FIV74b https://t.co/EO6eK8OTfQ')
# ** (0.5472031, '@dama_prohibida Entonces tienes dos soluciones cuando de amor se trate: ir con el sujetador de otro color, o directamente, ir sin sujetador 😈😈😈')
# ** (0.5198601, 'con q motivación voy a entrenar ahora si ya no veo a ninguna de las chicas 😭')
# ** (0.5107606, '♀️Desde el @Europarl_ES exigimos que la Política Exterior🇪🇺 tenga transversalidad de género.Urge proteger a las mujeres en cooperación al desarrollo y ayuda humanitaria.La negación del derecho al aborto también es violencia hacia las mujeres📺@MonicaSilvanaG en @France24_es https://t.co/lHmtsyckcI')
# ** (0.50964665, '@juanpidalpra @barbiedirocco No conoces a quienes han muerto porque reclamaban de esa prostitución forzada el pago del cliente que los jodio, no conoces a quienes fueron tildados de promiscuos, asesinadxs en patota y mendigando en la calle porque no tienen trabajo, cobertura de salud  o lo han perdido todo')

# %% [markdown]
# ### Select some samples to analyze
#
# You can select the samples with more confidence, those with less confidence, a mix of both, or simply the ones you consider more interesting.
#
#
#
# **Try not to choose the same samples that I’ve selected, and Justify your decision**.

# %%
# Make your own selection

# COMPLETE !
fpositive_samples = [

]

fnegative_samples = [

]

# %%
from ferret import Benchmark
from IPython.display import display_html

# selecting the benchmark
bench = Benchmark(model, tokenizer)#, explainers=[s,l])
# If you have trouble with this benchmark (runtime errors), try using just those two explainers.
    #from ferret.explainers.shap import SHAPExplainer
    #from ferret.explainers.lime import LIMEExplainer
    #lexp = LIMEExplainer(model, tokenizer)
    #sexp = SHAPExplainer(model, tokenizer)
    #bench = Benchmark(model, tokenizer, explainers=[sexp,lexp])

def explain_this(benchmark, sentence, target):
    explanations = benchmark.explain(sentence, target=target)
    explanations_de = deduplicate(explanations)
    explanation_evaluations = benchmark.evaluate_explanations(explanations_de, target=target)
    print("Sentence:", sentence)
    print("Class:", target)
    tble = benchmark.show_table(explanations_de)
    tble2 = benchmark.show_evaluation_table(explanation_evaluations)
    display_html(tble.to_html(), raw=True)
    display_html(tble2.to_html(), raw=True)

# %% [markdown]
# ### Show explanations

# %%
for sample in fpositive_samples:
    print("False Positive:")
    explain_this(bench, sample, 1)
    print("\n\n")

for sample in fnegative_samples:
    print("False Negative:")
    explain_this(bench, sample, 0)
    print("\n\n")
# Out:
# False Positive:
# Explainer:   0%|          | 0/6 [00:00<?, ?it/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Explanation eval:   0%|          | 0/6 [00:00<?, ?it/s]
# Sentence: chacha un mes ignorándome y ahora me vai a felicitar cómo si nada? 🖕🏼
# Class: 1
# <style type="text/css">
# #T_b3f08_row0_col0 {
#   background-color: #efd9da;
#   color: #000000;
# }
# #T_b3f08_row0_col1 {
#   background-color: #f0e1e2;
#   color: #000000;
# }
# #T_b3f08_row0_col2, #T_b3f08_row1_col13, #T_b3f08_row3_col3, #T_b3f08_row3_col14, #T_b3f08_row4_col4, #T_b3f08_row5_col7, #T_b3f08_row5_col12, #T_b3f08_row5_col15 {
#   background-color: #e9edf0;
#   color: #000000;
# }
# #T_b3f08_row0_col3, #T_b3f08_row0_col7, #T_b3f08_row4_col5, #T_b3f08_row5_col6 {
#   background-color: #edeff1;
#   color: #000000;
# }
# #T_b3f08_row0_col4 {
#   background-color: #eed3d5;
#   color: #000000;
# }
# #T_b3f08_row0_col5, #T_b3f08_row5_col4 {
#   background-color: #eecfd1;
#   color: #000000;
# }
# #T_b3f08_row0_col6, #T_b3f08_row0_col10, #T_b3f08_row2_col3, #T_b3f08_row3_col6 {
#   background-color: #f2ebeb;
#   color: #000000;
# }
# #T_b3f08_row0_col8, #T_b3f08_row1_col1, #T_b3f08_row2_col11, #T_b3f08_row4_col11 {
#   background-color: #f0dedf;
#   color: #000000;
# }
# #T_b3f08_row0_col9, #T_b3f08_row1_col10, #T_b3f08_row2_col5, #T_b3f08_row2_col14 {
#   background-color: #f1eaea;
#   color: #000000;
# }
# #T_b3f08_row0_col11, #T_b3f08_row1_col2, #T_b3f08_row5_col13 {
#   background-color: #ebeef0;
#   color: #000000;
# }
# #T_b3f08_row0_col12, #T_b3f08_row1_col12, #T_b3f08_row2_col6, #T_b3f08_row2_col10, #T_b3f08_row2_col12, #T_b3f08_row2_col13, #T_b3f08_row2_col15, #T_b3f08_row3_col5, #T_b3f08_row4_col1, #T_b3f08_row4_col7 {
#   background-color: #f2efef;
#   color: #000000;
# }
# #T_b3f08_row0_col13, #T_b3f08_row0_col15, #T_b3f08_row2_col2, #T_b3f08_row3_col4 {
#   background-color: #f2eded;
#   color: #000000;
# }
# #T_b3f08_row0_col14, #T_b3f08_row2_col7, #T_b3f08_row2_col8 {
#   background-color: #f2eeee;
#   color: #000000;
# }
# #T_b3f08_row1_col0, #T_b3f08_row2_col0, #T_b3f08_row4_col9, #T_b3f08_row4_col14, #T_b3f08_row5_col5 {
#   background-color: #efdadb;
#   color: #000000;
# }
# #T_b3f08_row1_col3, #T_b3f08_row1_col5, #T_b3f08_row3_col12, #T_b3f08_row4_col10, #T_b3f08_row5_col10 {
#   background-color: #f1f1f2;
#   color: #000000;
# }
# #T_b3f08_row1_col4 {
#   background-color: #edc7ca;
#   color: #000000;
# }
# #T_b3f08_row1_col6, #T_b3f08_row1_col7, #T_b3f08_row3_col2, #T_b3f08_row3_col15, #T_b3f08_row5_col2 {
#   background-color: #f2f1f1;
#   color: #000000;
# }
# #T_b3f08_row1_col8, #T_b3f08_row4_col6, #T_b3f08_row4_col8, #T_b3f08_row4_col12, #T_b3f08_row5_col8, #T_b3f08_row5_col11 {
#   background-color: #eff0f2;
#   color: #000000;
# }
# #T_b3f08_row1_col9 {
#   background-color: #efd7d9;
#   color: #000000;
# }
# #T_b3f08_row1_col11 {
#   background-color: #e1e7ec;
#   color: #000000;
# }
# #T_b3f08_row1_col14, #T_b3f08_row4_col13 {
#   background-color: #f1e8e9;
#   color: #000000;
# }
# #T_b3f08_row1_col15 {
#   background-color: #e2e8ed;
#   color: #000000;
# }
# #T_b3f08_row2_col1 {
#   background-color: #ecc0c3;
#   color: #000000;
# }
# #T_b3f08_row2_col4, #T_b3f08_row4_col15 {
#   background-color: #f0e3e3;
#   color: #000000;
# }
# #T_b3f08_row2_col9 {
#   background-color: #f0ddde;
#   color: #000000;
# }
# #T_b3f08_row3_col0, #T_b3f08_row5_col0, #T_b3f08_row5_col3 {
#   background-color: #f1e5e6;
#   color: #000000;
# }
# #T_b3f08_row3_col1 {
#   background-color: #d3dee6;
#   color: #000000;
# }
# #T_b3f08_row3_col7 {
#   background-color: #f1e4e5;
#   color: #000000;
# }
# #T_b3f08_row3_col8 {
#   background-color: #dce3ea;
#   color: #000000;
# }
# #T_b3f08_row3_col9 {
#   background-color: #d2dde6;
#   color: #000000;
# }
# #T_b3f08_row3_col10, #T_b3f08_row3_col11, #T_b3f08_row4_col2 {
#   background-color: #f1e7e7;
#   color: #000000;
# }
# #T_b3f08_row3_col13 {
#   background-color: #e4e9ed;
#   color: #000000;
# }
# #T_b3f08_row4_col0 {
#   background-color: #d5dfe7;
#   color: #000000;
# }
# #T_b3f08_row4_col3, #T_b3f08_row5_col1 {
#   background-color: #f0e0e1;
#   color: #000000;
# }
# #T_b3f08_row5_col9, #T_b3f08_row5_col14 {
#   background-color: #efdbdd;
#   color: #000000;
# }
# </style>
# <table id="T_b3f08">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Token</th>
#       <th id="T_b3f08_level0_col0" class="col_heading level0 col0" >▁ch</th>
#       <th id="T_b3f08_level0_col1" class="col_heading level0 col1" >acha</th>
#       <th id="T_b3f08_level0_col2" class="col_heading level0 col2" >▁un</th>
#       <th id="T_b3f08_level0_col3" class="col_heading level0 col3" >▁mes</th>
#       <th id="T_b3f08_level0_col4" class="col_heading level0 col4" >▁ignor</th>
#       <th id="T_b3f08_level0_col5" class="col_heading level0 col5" >andome</th>
#       <th id="T_b3f08_level0_col6" class="col_heading level0 col6" >▁y</th>
#       <th id="T_b3f08_level0_col7" class="col_heading level0 col7" >▁ahora</th>
#       <th id="T_b3f08_level0_col8" class="col_heading level0 col8" >▁me</th>
#       <th id="T_b3f08_level0_col9" class="col_heading level0 col9" >▁vai</th>
#       <th id="T_b3f08_level0_col10" class="col_heading level0 col10" >▁a</th>
#       <th id="T_b3f08_level0_col11" class="col_heading level0 col11" >▁felicitar</th>
#       <th id="T_b3f08_level0_col12" class="col_heading level0 col12" >▁como</th>
#       <th id="T_b3f08_level0_col13" class="col_heading level0 col13" >▁si</th>
#       <th id="T_b3f08_level0_col14" class="col_heading level0 col14" >▁nada?</th>
#       <th id="T_b3f08_level0_col15" class="col_heading level0 col15" >▁</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b3f08_level0_row0" class="row_heading level0 row0" >Partition SHAP</th>
#       <td id="T_b3f08_row0_col0" class="data row0 col0" >0.13</td>
#       <td id="T_b3f08_row0_col1" class="data row0 col1" >0.09</td>
#       <td id="T_b3f08_row0_col2" class="data row0 col2" >-0.04</td>
#       <td id="T_b3f08_row0_col3" class="data row0 col3" >-0.02</td>
#       <td id="T_b3f08_row0_col4" class="data row0 col4" >0.16</td>
#       <td id="T_b3f08_row0_col5" class="data row0 col5" >0.19</td>
#       <td id="T_b3f08_row0_col6" class="data row0 col6" >0.04</td>
#       <td id="T_b3f08_row0_col7" class="data row0 col7" >-0.02</td>
#       <td id="T_b3f08_row0_col8" class="data row0 col8" >0.10</td>
#       <td id="T_b3f08_row0_col9" class="data row0 col9" >0.04</td>
#       <td id="T_b3f08_row0_col10" class="data row0 col10" >0.04</td>
#       <td id="T_b3f08_row0_col11" class="data row0 col11" >-0.03</td>
#       <td id="T_b3f08_row0_col12" class="data row0 col12" >0.01</td>
#       <td id="T_b3f08_row0_col13" class="data row0 col13" >0.03</td>
#       <td id="T_b3f08_row0_col14" class="data row0 col14" >0.02</td>
#       <td id="T_b3f08_row0_col15" class="data row0 col15" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_b3f08_level0_row1" class="row_heading level0 row1" >LIME</th>
#       <td id="T_b3f08_row1_col0" class="data row1 col0" >0.13</td>
#       <td id="T_b3f08_row1_col1" class="data row1 col1" >0.11</td>
#       <td id="T_b3f08_row1_col2" class="data row1 col2" >-0.04</td>
#       <td id="T_b3f08_row1_col3" class="data row1 col3" >-0.00</td>
#       <td id="T_b3f08_row1_col4" class="data row1 col4" >0.23</td>
#       <td id="T_b3f08_row1_col5" class="data row1 col5" >-0.00</td>
#       <td id="T_b3f08_row1_col6" class="data row1 col6" >0.00</td>
#       <td id="T_b3f08_row1_col7" class="data row1 col7" >0.01</td>
#       <td id="T_b3f08_row1_col8" class="data row1 col8" >-0.01</td>
#       <td id="T_b3f08_row1_col9" class="data row1 col9" >0.14</td>
#       <td id="T_b3f08_row1_col10" class="data row1 col10" >0.04</td>
#       <td id="T_b3f08_row1_col11" class="data row1 col11" >-0.09</td>
#       <td id="T_b3f08_row1_col12" class="data row1 col12" >0.01</td>
#       <td id="T_b3f08_row1_col13" class="data row1 col13" >-0.04</td>
#       <td id="T_b3f08_row1_col14" class="data row1 col14" >0.05</td>
#       <td id="T_b3f08_row1_col15" class="data row1 col15" >-0.08</td>
#     </tr>
#     <tr>
#       <th id="T_b3f08_level0_row2" class="row_heading level0 row2" >Gradient</th>
#       <td id="T_b3f08_row2_col0" class="data row2 col0" >0.13</td>
#       <td id="T_b3f08_row2_col1" class="data row2 col1" >0.27</td>
#       <td id="T_b3f08_row2_col2" class="data row2 col2" >0.03</td>
#       <td id="T_b3f08_row2_col3" class="data row2 col3" >0.04</td>
#       <td id="T_b3f08_row2_col4" class="data row2 col4" >0.08</td>
#       <td id="T_b3f08_row2_col5" class="data row2 col5" >0.05</td>
# <style type="text/css">
# #T_f2ba1_row0_col0 {
#   background-color: #e79ea3;
#   color: #000000;
#   background-color: #9f419f;
#   color: #f1f1f1;
# }
# #T_f2ba1_row0_col1 {
#   background-color: #f0dedf;
#   color: #000000;
#   background-color: #bf85bf;
#   color: #f1f1f1;
# }
# #T_f2ba1_row0_col2 {
#   background-color: #ebbdc1;
#   color: #000000;
#   background-color: #a956a9;
#   color: #f1f1f1;
# }
# #T_f2ba1_row1_col0 {
#   background-color: #eab0b5;
#   color: #000000;
#   background-color: #a54da5;
#   color: #f1f1f1;
# }
# #T_f2ba1_row1_col1 {
#   background-color: #f1eaea;
#   color: #000000;
#   background-color: #bc7dbc;
#   color: #f1f1f1;
# }
# #T_f2ba1_row1_col2 {
#   background-color: #edc7ca;
#   color: #000000;
#   background-color: #ac5cac;
#   color: #f1f1f1;
# }
# #T_f2ba1_row2_col0 {
#   background-color: #ebbbbe;
#   color: #000000;
#   background-color: #a854a8;
#   color: #f1f1f1;
# }
# #T_f2ba1_row2_col1 {
#   background-color: #f2eded;
#   color: #000000;
#   background-color: #bb7bbb;
#   color: #f1f1f1;
# }
# #T_f2ba1_row2_col2 {
#   background-color: #e6959b;
#   color: #f1f1f1;
#   background-color: #9c3b9c;
#   color: #f1f1f1;
# }
# #T_f2ba1_row3_col0, #T_f2ba1_row5_col0 {
#   background-color: #edc6c9;
#   color: #000000;
#   background-color: #ac5bac;
#   color: #f1f1f1;
# }
# #T_f2ba1_row3_col1 {
#   background-color: #e79ba1;
#   color: #000000;
#   background-color: #d5b1d5;
#   color: #000000;
# }
# #T_f2ba1_row3_col2, #T_f2ba1_row4_col0 {
#   background-color: #f0e3e3;
#   color: #000000;
#   background-color: #b56eb5;
#   color: #f1f1f1;
# }
# #T_f2ba1_row4_col1 {
#   background-color: #eab3b7;
#   color: #000000;
#   background-color: #cda1cd;
#   color: #000000;
# }
# #T_f2ba1_row4_col2 {
#   background-color: #d3dee6;
#   color: #000000;
#   background-color: #c38cc3;
#   color: #f1f1f1;
# }
# #T_f2ba1_row5_col1 {
#   background-color: #eed0d2;
#   color: #000000;
#   background-color: #c48ec4;
#   color: #f1f1f1;
# }
# #T_f2ba1_row5_col2 {
#   background-color: #e8a5aa;
#   color: #000000;
#   background-color: #a146a1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f2ba1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f2ba1_level0_col0" class="col_heading level0 col0" >aopc_compr</th>
#       <th id="T_f2ba1_level0_col1" class="col_heading level0 col1" >aopc_suff</th>
#       <th id="T_f2ba1_level0_col2" class="col_heading level0 col2" >taucorr_loo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2ba1_level0_row0" class="row_heading level0 row0" >Partition SHAP</th>
#       <td id="T_f2ba1_row0_col0" class="data row0 col0" >0.46</td>
#       <td id="T_f2ba1_row0_col1" class="data row0 col1" >0.11</td>
#       <td id="T_f2ba1_row0_col2" class="data row0 col2" >0.28</td>
#     </tr>
#     <tr>
#       <th id="T_f2ba1_level0_row1" class="row_heading level0 row1" >LIME</th>
#       <td id="T_f2ba1_row1_col0" class="data row1 col0" >0.36</td>
#       <td id="T_f2ba1_row1_col1" class="data row1 col1" >0.04</td>
#       <td id="T_f2ba1_row1_col2" class="data row1 col2" >0.23</td>
#     </tr>
#     <tr>
#       <th id="T_f2ba1_level0_row2" class="row_heading level0 row2" >Gradient</th>
#       <td id="T_f2ba1_row2_col0" class="data row2 col0" >0.30</td>
#       <td id="T_f2ba1_row2_col1" class="data row2 col1" >0.02</td>
#       <td id="T_f2ba1_row2_col2" class="data row2 col2" >0.50</td>
#     </tr>
#     <tr>
#       <th id="T_f2ba1_level0_row3" class="row_heading level0 row3" >Gradient (x Input)</th>
#       <td id="T_f2ba1_row3_col0" class="data row3 col0" >0.24</td>
#       <td id="T_f2ba1_row3_col1" class="data row3 col1" >0.47</td>
#       <td id="T_f2ba1_row3_col2" class="data row3 col2" >0.08</td>
#     </tr>
#     <tr>
#       <th id="T_f2ba1_level0_row4" class="row_heading level0 row4" >Integrated Gradient</th>
#       <td id="T_f2ba1_row4_col0" class="data row4 col0" >0.08</td>
#       <td id="T_f2ba1_row4_col1" class="data row4 col1" >0.34</td>
#       <td id="T_f2ba1_row4_col2" class="data row4 col2" >-0.17</td>
#     </tr>
#     <tr>
#       <th id="T_f2ba1_level0_row5" class="row_heading level0 row5" >Integrated Gradient (x Input)</th>
#       <td id="T_f2ba1_row5_col0" class="data row5 col0" >0.24</td>
#       <td id="T_f2ba1_row5_col1" class="data row5 col1" >0.19</td>
#       <td id="T_f2ba1_row5_col2" class="data row5 col2" >0.42</td>
#     </tr>
#   </tbody>
# </table>
# False Positive:
# Explainer:   0%|          | 0/6 [00:00<?, ?it/s]
# Explanation eval:   0%|          | 0/6 [00:00<?, ?it/s]
# Sentence: Adoro las fotos pero están usando mal el término, el manspreading no es solo sentarse con las piernas abiertas. :/ https://t.co/EMrpmRrSdD
# Class: 1
# <style type="text/css">
# #T_b5212_row0_col0, #T_b5212_row0_col3, #T_b5212_row0_col4, #T_b5212_row0_col8, #T_b5212_row0_col9, #T_b5212_row0_col15, #T_b5212_row0_col18, #T_b5212_row0_col23, #T_b5212_row0_col26, #T_b5212_row0_col28, #T_b5212_row0_col29, #T_b5212_row0_col30, #T_b5212_row0_col31, #T_b5212_row0_col32, #T_b5212_row0_col33, #T_b5212_row0_col35, #T_b5212_row0_col36, #T_b5212_row1_col10, #T_b5212_row1_col17, #T_b5212_row1_col19, #T_b5212_row1_col36, #T_b5212_row3_col3, #T_b5212_row3_col6, #T_b5212_row3_col17, #T_b5212_row3_col32, #T_b5212_row3_col36, #T_b5212_row4_col4, #T_b5212_row4_col8, #T_b5212_row4_col26, #T_b5212_row5_col7, #T_b5212_row5_col12, #T_b5212_row5_col17, #T_b5212_row5_col24, #T_b5212_row5_col27, #T_b5212_row5_col30, #T_b5212_row5_col31, #T_b5212_row5_col35 {
#   background-color: #f1f1f2;
#   color: #000000;
# }
# #T_b5212_row0_col1, #T_b5212_row0_col6, #T_b5212_row1_col0, #T_b5212_row1_col6, #T_b5212_row1_col7, #T_b5212_row1_col22, #T_b5212_row1_col30, #T_b5212_row1_col31, #T_b5212_row2_col4, #T_b5212_row2_col6, #T_b5212_row2_col9, #T_b5212_row2_col10, #T_b5212_row2_col15, #T_b5212_row2_col16, #T_b5212_row2_col19, #T_b5212_row2_col20, #T_b5212_row2_col26, #T_b5212_row2_col29, #T_b5212_row2_col30, #T_b5212_row2_col32, #T_b5212_row2_col33, #T_b5212_row2_col34, #T_b5212_row2_col35, #T_b5212_row2_col37, #T_b5212_row3_col4, #T_b5212_row3_col10, #T_b5212_row3_col12, #T_b5212_row3_col15, #T_b5212_row3_col16, #T_b5212_row3_col27, #T_b5212_row3_col29, #T_b5212_row3_col30, #T_b5212_row3_col34, #T_b5212_row3_col35, #T_b5212_row4_col5, #T_b5212_row4_col10, #T_b5212_row4_col12, #T_b5212_row4_col16, #T_b5212_row4_col27, #T_b5212_row4_col32, #T_b5212_row5_col3, #T_b5212_row5_col9, #T_b5212_row5_col22, #T_b5212_row5_col23, #T_b5212_row5_col29, #T_b5212_row5_col32, #T_b5212_row5_col33, #T_b5212_row5_col34 {
#   background-color: #f2efef;
#   color: #000000;
# }
# #T_b5212_row0_col2, #T_b5212_row0_col7, #T_b5212_row0_col25, #T_b5212_row1_col5, #T_b5212_row1_col18, #T_b5212_row1_col27, #T_b5212_row1_col28, #T_b5212_row1_col35, #T_b5212_row3_col0, #T_b5212_row3_col18, #T_b5212_row3_col19, #T_b5212_row3_col20, #T_b5212_row3_col26, #T_b5212_row4_col6, #T_b5212_row4_col20, #T_b5212_row4_col23, #T_b5212_row4_col29, #T_b5212_row4_col30, #T_b5212_row4_col36, #T_b5212_row5_col25 {
#   background-color: #eff0f2;
#   color: #000000;
# }
# #T_b5212_row0_col5, #T_b5212_row0_col10, #T_b5212_row0_col22, #T_b5212_row0_col24, #T_b5212_row0_col27, #T_b5212_row0_col34, #T_b5212_row0_col37, #T_b5212_row1_col3, #T_b5212_row1_col16, #T_b5212_row1_col25, #T_b5212_row1_col26, #T_b5212_row1_col29, #T_b5212_row1_col32, #T_b5212_row1_col33, #T_b5212_row1_col37, #T_b5212_row2_col1, #T_b5212_row2_col3, #T_b5212_row2_col7, #T_b5212_row2_col27, #T_b5212_row2_col31, #T_b5212_row2_col36, #T_b5212_row3_col7, #T_b5212_row3_col13, #T_b5212_row3_col31, #T_b5212_row3_col37, #T_b5212_row4_col3, #T_b5212_row4_col33, #T_b5212_row5_col5, #T_b5212_row5_col16, #T_b5212_row5_col20, #T_b5212_row5_col26, #T_b5212_row5_col28 {
#   background-color: #f2f1f1;
#   color: #000000;
# }
# #T_b5212_row0_col11 {
#   background-color: #e8a2a7;
#   color: #000000;
# }
# #T_b5212_row0_col12, #T_b5212_row3_col2, #T_b5212_row5_col1, #T_b5212_row5_col8 {
#   background-color: #f2ebeb;
#   color: #000000;
# }
# #T_b5212_row0_col13 {
#   background-color: #edc7ca;
#   color: #000000;
# }
# #T_b5212_row0_col14, #T_b5212_row4_col18 {
#   background-color: #e8ecef;
#   color: #000000;
# }
# #T_b5212_row0_col16, #T_b5212_row0_col17, #T_b5212_row0_col19, #T_b5212_row1_col8, #T_b5212_row1_col15, #T_b5212_row3_col25, #T_b5212_row4_col13, #T_b5212_row4_col17, #T_b5212_row4_col19, #T_b5212_row4_col31, #T_b5212_row4_col34, #T_b5212_row5_col10, #T_b5212_row5_col36 {
#   background-color: #edeff1;
#   color: #000000;
# }
# #T_b5212_row0_col20, #T_b5212_row1_col4, #T_b5212_row1_col9, #T_b5212_row1_col20, #T_b5212_row1_col23, #T_b5212_row2_col13, #T_b5212_row2_col17, #T_b5212_row2_col28, #T_b5212_row3_col1, #T_b5212_row3_col9, #T_b5212_row3_col28, #T_b5212_row4_col1, #T_b5212_row4_col7, #T_b5212_row4_col15, #T_b5212_row5_col0, #T_b5212_row5_col4, #T_b5212_row5_col15, #T_b5212_row5_col18 {
#   background-color: #f2eeee;
#   color: #000000;
# }
# #T_b5212_row0_col21, #T_b5212_row1_col12, #T_b5212_row2_col14, #T_b5212_row2_col25, #T_b5212_row4_col25 {
#   background-color: #f1e7e7;
#   color: #000000;
# }
# #T_b5212_row1_col1, #T_b5212_row1_col34, #T_b5212_row2_col2, #T_b5212_row2_col5, #T_b5212_row2_col23, #T_b5212_row5_col6, #T_b5212_row5_col13, #T_b5212_row5_col19 {
#   background-color: #f2eded;
#   color: #000000;
# }
# #T_b5212_row1_col2, #T_b5212_row3_col33, #T_b5212_row4_col0, #T_b5212_row4_col35, #T_b5212_row5_col2 {
#   background-color: #eceef1;
#   color: #000000;
# }
# #T_b5212_row1_col11 {
#   background-color: #eab3b7;
#   color: #000000;
# }
# #T_b5212_row1_col13 {
#   background-color: #f0dedf;
#   color: #000000;
# }
# #T_b5212_row1_col14, #T_b5212_row2_col0, #T_b5212_row2_col8, #T_b5212_row2_col12, #T_b5212_row2_col24, #T_b5212_row5_col21, #T_b5212_row5_col37 {
#   background-color: #f1eaea;
#   color: #000000;
# }
# #T_b5212_row1_col21, #T_b5212_row2_col18, #T_b5212_row4_col24 {
#   background-color: #f1e5e6;
#   color: #000000;
# }
# #T_b5212_row1_col24, #T_b5212_row4_col11, #T_b5212_row4_col28 {
#   background-color: #ebeef0;
#   color: #000000;
# }
# #T_b5212_row2_col11 {
#   background-color: #efdbdd;
#   color: #000000;
# }
# #T_b5212_row2_col21 {
#   background-color: #f0e1e2;
#   color: #000000;
# }
# #T_b5212_row2_col22, #T_b5212_row3_col5, #T_b5212_row3_col8, #T_b5212_row3_col21, #T_b5212_row3_col23, #T_b5212_row3_col24 {
#   background-color: #f1e8e9;
#   color: #000000;
# }
# #T_b5212_row3_col11, #T_b5212_row3_col14 {
#   background-color: #eed3d5;
#   color: #000000;
# }
# #T_b5212_row3_col22, #T_b5212_row4_col2, #T_b5212_row4_col9 {
#   background-color: #e9edf0;
#   color: #000000;
# }
# #T_b5212_row4_col14 {
#   background-color: #e7ebee;
#   color: #000000;
# }
# #T_b5212_row4_col21 {
#   background-color: #f0e0e1;
#   color: #000000;
# }
# #T_b5212_row4_col22 {
#   background-color: #e5eaee;
#   color: #000000;
# }
# #T_b5212_row4_col37 {
#   background-color: #e4e9ed;
#   color: #000000;
# }
# #T_b5212_row5_col11 {
#   background-color: #edc6c9;
#   color: #000000;
# }
# #T_b5212_row5_col14 {
#   background-color: #ecc5c7;
#   color: #000000;
# }
# </style>
# <table id="T_b5212">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Token</th>
#       <th id="T_b5212_level0_col0" class="col_heading level0 col0" >▁adoro</th>
#       <th id="T_b5212_level0_col1" class="col_heading level0 col1" >▁las_1</th>
#       <th id="T_b5212_level0_col2" class="col_heading level0 col2" >▁fotos</th>
#       <th id="T_b5212_level0_col3" class="col_heading level0 col3" >▁pero</th>
#       <th id="T_b5212_level0_col4" class="col_heading level0 col4" >▁estan</th>
#       <th id="T_b5212_level0_col5" class="col_heading level0 col5" >▁usando</th>
#       <th id="T_b5212_level0_col6" class="col_heading level0 col6" >▁mal</th>
#       <th id="T_b5212_level0_col7" class="col_heading level0 col7" >▁el_1</th>
#       <th id="T_b5212_level0_col8" class="col_heading level0 col8" >▁termin</th>
#       <th id="T_b5212_level0_col9" class="col_heading level0 col9" >o,</th>
#       <th id="T_b5212_level0_col10" class="col_heading level0 col10" >▁el_2</th>
#       <th id="T_b5212_level0_col11" class="col_heading level0 col11" >▁mans</th>
#       <th id="T_b5212_level0_col12" class="col_heading level0 col12" >pre</th>
#       <th id="T_b5212_level0_col13" class="col_heading level0 col13" >ad</th>
#       <th id="T_b5212_level0_col14" class="col_heading level0 col14" >ing</th>
#       <th id="T_b5212_level0_col15" class="col_heading level0 col15" >▁no</th>
#       <th id="T_b5212_level0_col16" class="col_heading level0 col16" >▁es</th>
#       <th id="T_b5212_level0_col17" class="col_heading level0 col17" >▁solo</th>
#       <th id="T_b5212_level0_col18" class="col_heading level0 col18" >▁sentarse</th>
#       <th id="T_b5212_level0_col19" class="col_heading level0 col19" >▁con</th>
#       <th id="T_b5212_level0_col20" class="col_heading level0 col20" >▁las_2</th>
#       <th id="T_b5212_l
# <style type="text/css">
# #T_1b8b6_row0_col0 {
#   background-color: #dc4752;
#   color: #f1f1f1;
#   background-color: #840884;
#   color: #f1f1f1;
# }
# #T_1b8b6_row0_col1 {
#   background-color: #efdadb;
#   color: #000000;
#   background-color: #c187c1;
#   color: #f1f1f1;
# }
# #T_1b8b6_row0_col2 {
#   background-color: #e1e7ec;
#   color: #000000;
#   background-color: #bf83bf;
#   color: #f1f1f1;
# }
# #T_1b8b6_row1_col0 {
#   background-color: #db4651;
#   color: #f1f1f1;
#   background-color: #840884;
#   color: #f1f1f1;
# }
# #T_1b8b6_row1_col1 {
#   background-color: #f1eaea;
#   color: #000000;
#   background-color: #bc7dbc;
#   color: #f1f1f1;
# }
# #T_1b8b6_row1_col2 {
#   background-color: #ecc3c6;
#   color: #000000;
#   background-color: #ab59ab;
#   color: #f1f1f1;
# }
# #T_1b8b6_row2_col0 {
#   background-color: #df5e68;
#   color: #f1f1f1;
#   background-color: #8b188b;
#   color: #f1f1f1;
# }
# #T_1b8b6_row2_col1 {
#   background-color: #f1e4e5;
#   color: #000000;
#   background-color: #be81be;
#   color: #f1f1f1;
# }
# #T_1b8b6_row2_col2 {
#   background-color: #e5eaee;
#   color: #000000;
#   background-color: #bd80bd;
#   color: #f1f1f1;
# }
# #T_1b8b6_row3_col0 {
#   background-color: #dd4f59;
#   color: #f1f1f1;
#   background-color: #860d86;
#   color: #f1f1f1;
# }
# #T_1b8b6_row3_col1 {
#   background-color: #ebbcbf;
#   color: #000000;
#   background-color: #ca9bca;
#   color: #f1f1f1;
# }
# #T_1b8b6_row3_col2 {
#   background-color: #efd6d7;
#   color: #000000;
#   background-color: #b166b1;
#   color: #f1f1f1;
# }
# #T_1b8b6_row4_col0 {
#   background-color: #f2f1f1;
#   color: #000000;
#   background-color: #b977b9;
#   color: #f1f1f1;
# }
# #T_1b8b6_row4_col1 {
#   background-color: #de5963;
#   color: #f1f1f1;
#   background-color: #e9dce9;
#   color: #000000;
# }
# #T_1b8b6_row4_col2 {
#   background-color: #dae3e9;
#   color: #000000;
#   background-color: #c187c1;
#   color: #f1f1f1;
# }
# #T_1b8b6_row5_col0 {
#   background-color: #dc4c56;
#   color: #f1f1f1;
#   background-color: #850b85;
#   color: #f1f1f1;
# }
# #T_1b8b6_row5_col1 {
#   background-color: #efd9da;
#   color: #000000;
#   background-color: #c188c1;
#   color: #f1f1f1;
# }
# #T_1b8b6_row5_col2 {
#   background-color: #f0e0e1;
#   color: #000000;
#   background-color: #b46cb4;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1b8b6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1b8b6_level0_col0" class="col_heading level0 col0" >aopc_compr</th>
#       <th id="T_1b8b6_level0_col1" class="col_heading level0 col1" >aopc_suff</th>
#       <th id="T_1b8b6_level0_col2" class="col_heading level0 col2" >taucorr_loo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b8b6_level0_row0" class="row_heading level0 row0" >Partition SHAP</th>
#       <td id="T_1b8b6_row0_col0" class="data row0 col0" >0.93</td>
#       <td id="T_1b8b6_row0_col1" class="data row0 col1" >0.13</td>
#       <td id="T_1b8b6_row0_col2" class="data row0 col2" >-0.09</td>
#     </tr>
#     <tr>
#       <th id="T_1b8b6_level0_row1" class="row_heading level0 row1" >LIME</th>
#       <td id="T_1b8b6_row1_col0" class="data row1 col0" >0.93</td>
#       <td id="T_1b8b6_row1_col1" class="data row1 col1" >0.04</td>
#       <td id="T_1b8b6_row1_col2" class="data row1 col2" >0.25</td>
#     </tr>
#     <tr>
#       <th id="T_1b8b6_level0_row2" class="row_heading level0 row2" >Gradient</th>
#       <td id="T_1b8b6_row2_col0" class="data row2 col0" >0.80</td>
#       <td id="T_1b8b6_row2_col1" class="data row2 col1" >0.07</td>
#       <td id="T_1b8b6_row2_col2" class="data row2 col2" >-0.07</td>
#     </tr>
#     <tr>
#       <th id="T_1b8b6_level0_row3" class="row_heading level0 row3" >Gradient (x Input)</th>
#       <td id="T_1b8b6_row3_col0" class="data row3 col0" >0.88</td>
#       <td id="T_1b8b6_row3_col1" class="data row3 col1" >0.29</td>
#       <td id="T_1b8b6_row3_col2" class="data row3 col2" >0.16</td>
#     </tr>
#     <tr>
#       <th id="T_1b8b6_level0_row4" class="row_heading level0 row4" >Integrated Gradient</th>
#       <td id="T_1b8b6_row4_col0" class="data row4 col0" >0.00</td>
#       <td id="T_1b8b6_row4_col1" class="data row4 col1" >0.83</td>
#       <td id="T_1b8b6_row4_col2" class="data row4 col2" >-0.13</td>
#     </tr>
#     <tr>
#       <th id="T_1b8b6_level0_row5" class="row_heading level0 row5" >Integrated Gradient (x Input)</th>
#       <td id="T_1b8b6_row5_col0" class="data row5 col0" >0.90</td>
#       <td id="T_1b8b6_row5_col1" class="data row5 col1" >0.13</td>
#       <td id="T_1b8b6_row5_col2" class="data row5 col2" >0.10</td>
#     </tr>
#   </tbody>
# </table>
# False Negative:
# Explainer:   0%|          | 0/6 [00:00<?, ?it/s]
# Explanation eval:   0%|          | 0/6 [00:00<?, ?it/s]
# Sentence: Ando mas relajado que papá con hija fea por que no salgo en estos tik toks😮‍💨
# Class: 0
# <style type="text/css">
# #T_0daf8_row0_col0, #T_0daf8_row0_col2, #T_0daf8_row2_col3, #T_0daf8_row4_col3 {
#   background-color: #f1e5e6;
#   color: #000000;
# }
# #T_0daf8_row0_col1, #T_0daf8_row1_col1, #T_0daf8_row2_col6, #T_0daf8_row2_col12, #T_0daf8_row3_col12, #T_0daf8_row5_col1 {
#   background-color: #f1eaea;
#   color: #000000;
# }
# #T_0daf8_row0_col3, #T_0daf8_row3_col3 {
#   background-color: #f0e3e3;
#   color: #000000;
# }
# #T_0daf8_row0_col4, #T_0daf8_row1_col8, #T_0daf8_row1_col11, #T_0daf8_row5_col7 {
#   background-color: #e7ebee;
#   color: #000000;
# }
# #T_0daf8_row0_col5, #T_0daf8_row0_col14, #T_0daf8_row1_col10, #T_0daf8_row1_col14, #T_0daf8_row2_col17, #T_0daf8_row3_col1, #T_0daf8_row3_col4, #T_0daf8_row3_col6, #T_0daf8_row4_col1, #T_0daf8_row4_col9, #T_0daf8_row5_col11 {
#   background-color: #f2eded;
#   color: #000000;
# }
# #T_0daf8_row0_col6 {
#   background-color: #efd9da;
#   color: #000000;
# }
# #T_0daf8_row0_col7, #T_0daf8_row4_col15 {
#   background-color: #dee5eb;
#   color: #000000;
# }
# #T_0daf8_row0_col8 {
#   background-color: #cbd8e3;
#   color: #000000;
# }
# #T_0daf8_row0_col9, #T_0daf8_row1_col15, #T_0daf8_row3_col9, #T_0daf8_row4_col6, #T_0daf8_row5_col15, #T_0daf8_row5_col17 {
#   background-color: #eff0f2;
#   color: #000000;
# }
# #T_0daf8_row0_col10, #T_0daf8_row2_col11, #T_0daf8_row3_col14, #T_0daf8_row4_col13, #T_0daf8_row4_col17, #T_0daf8_row5_col16 {
#   background-color: #f2f1f1;
#   color: #000000;
# }
# #T_0daf8_row0_col11, #T_0daf8_row4_col2, #T_0daf8_row4_col11, #T_0daf8_row5_col8 {
#   background-color: #eceef1;
#   color: #000000;
# }
# #T_0daf8_row0_col12, #T_0daf8_row0_col16, #T_0daf8_row1_col9 {
#   background-color: #ebeef0;
#   color: #000000;
# }
# #T_0daf8_row0_col13, #T_0daf8_row1_col17, #T_0daf8_row2_col10, #T_0daf8_row2_col13, #T_0daf8_row3_col16, #T_0daf8_row5_col13 {
#   background-color: #f2efef;
#   color: #000000;
# }
# #T_0daf8_row0_col15, #T_0daf8_row1_col12, #T_0daf8_row3_col5, #T_0daf8_row4_col4, #T_0daf8_row4_col5, #T_0daf8_row4_col14 {
#   background-color: #edeff1;
#   color: #000000;
# }
# #T_0daf8_row0_col17, #T_0daf8_row5_col4 {
#   background-color: #f2ebeb;
#   color: #000000;
# }
# #T_0daf8_row1_col0 {
#   background-color: #efdadb;
#   color: #000000;
# }
# #T_0daf8_row1_col2, #T_0daf8_row2_col8 {
#   background-color: #eecfd1;
#   color: #000000;
# }
# #T_0daf8_row1_col3 {
#   background-color: #f0e1e2;
#   color: #000000;
# }
# #T_0daf8_row1_col4, #T_0daf8_row3_col0 {
#   background-color: #e9edf0;
#   color: #000000;
# }
# #T_0daf8_row1_col5 {
#   background-color: #f1e8e9;
#   color: #000000;
# }
# #T_0daf8_row1_col6, #T_0daf8_row2_col0, #T_0daf8_row2_col2, #T_0daf8_row3_col8, #T_0daf8_row3_col17, #T_0daf8_row4_col12 {
#   background-color: #f1e7e7;
#   color: #000000;
# }
# #T_0daf8_row1_col7, #T_0daf8_row5_col0 {
#   background-color: #e8ecef;
#   color: #000000;
# }
# #T_0daf8_row1_col13, #T_0daf8_row3_col10, #T_0daf8_row3_col11, #T_0daf8_row3_col13, #T_0daf8_row4_col0, #T_0daf8_row4_col10, #T_0daf8_row5_col9 {
#   background-color: #f1f1f2;
#   color: #000000;
# }
# #T_0daf8_row1_col16, #T_0daf8_row5_col6 {
#   background-color: #e2e8ed;
#   color: #000000;
# }
# #T_0daf8_row2_col1, #T_0daf8_row2_col4, #T_0daf8_row2_col9, #T_0daf8_row2_col14, #T_0daf8_row2_col16, #T_0daf8_row4_col16, #T_0daf8_row5_col10, #T_0daf8_row5_col14 {
#   background-color: #f2eeee;
#   color: #000000;
# }
# #T_0daf8_row2_col5, #T_0daf8_row3_col15 {
#   background-color: #f0e0e1;
#   color: #000000;
# }
# #T_0daf8_row2_col7, #T_0daf8_row5_col3 {
#   background-color: #eed0d2;
#   color: #000000;
# }
# #T_0daf8_row2_col15, #T_0daf8_row3_col2 {
#   background-color: #f1e4e5;
#   color: #000000;
# }
# #T_0daf8_row3_col7 {
#   background-color: #aec5d6;
#   color: #000000;
# }
# #T_0daf8_row4_col7 {
#   background-color: #bfd0dd;
#   color: #000000;
# }
# #T_0daf8_row4_col8 {
#   background-color: #c2d2df;
#   color: #000000;
# }
# #T_0daf8_row5_col2 {
#   background-color: #efdbdd;
#   color: #000000;
# }
# #T_0daf8_row5_col5 {
#   background-color: #d2dde6;
#   color: #000000;
# }
# #T_0daf8_row5_col12 {
#   background-color: #dce3ea;
#   color: #000000;
# }
# </style>
# <table id="T_0daf8">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Token</th>
#       <th id="T_0daf8_level0_col0" class="col_heading level0 col0" >▁ando</th>
#       <th id="T_0daf8_level0_col1" class="col_heading level0 col1" >▁mas</th>
#       <th id="T_0daf8_level0_col2" class="col_heading level0 col2" >▁rela</th>
#       <th id="T_0daf8_level0_col3" class="col_heading level0 col3" >jado</th>
#       <th id="T_0daf8_level0_col4" class="col_heading level0 col4" >▁que_1</th>
#       <th id="T_0daf8_level0_col5" class="col_heading level0 col5" >▁papa</th>
#       <th id="T_0daf8_level0_col6" class="col_heading level0 col6" >▁con</th>
#       <th id="T_0daf8_level0_col7" class="col_heading level0 col7" >▁hija</th>
#       <th id="T_0daf8_level0_col8" class="col_heading level0 col8" >▁fea</th>
#       <th id="T_0daf8_level0_col9" class="col_heading level0 col9" >▁por</th>
#       <th id="T_0daf8_level0_col10" class="col_heading level0 col10" >▁que_2</th>
#       <th id="T_0daf8_level0_col11" class="col_heading level0 col11" >▁no</th>
#       <th id="T_0daf8_level0_col12" class="col_heading level0 col12" >▁salgo</th>
#       <th id="T_0daf8_level0_col13" class="col_heading level0 col13" >▁en</th>
#       <th id="T_0daf8_level0_col14" class="col_heading level0 col14" >▁estos</th>
#       <th id="T_0daf8_level0_col15" class="col_heading level0 col15" >▁tik</th>
#       <th id="T_0daf8_level0_col16" class="col_heading level0 col16" >▁to</th>
#       <th id="T_0daf8_level0_col17" class="col_heading level0 col17" >ks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0daf8_level0_row0" class="row_heading level0 row0" >Partition SHAP</th>
#       <td id="T_0daf8_row0_col0" class="data row0 col0" >0.07</td>
#       <td id="T_0daf8_row0_col1" class="data row0 col1" >0.05</td>
#       <td id="T_0daf8_row0_col2" class="data row0 col2" >0.07</td>
#       <td id="T_0daf8_row0_col3" class="data row0 col3" >0.09</td>
#       <td id="T_0daf8_row0_col4" class="data row0 col4" >-0.06</td>
#       <td id="T_0daf8_row0_col5" class="data row0 col5" >0.02</td>
#       <td id="T_0daf8_row0_col6" class="data row0 col6" >0.14</td>
#       <td id="T_0daf8_row0_col7" class="data row0 col7" >-0.10</td>
#       <td id="T_0daf8_row0_col8" class="data row0 col8" >-0.22</td>
#       <td id="T_0daf8_row0_col9" class="data row0 col9" >-0.01</td>
#       <td id="T_0daf8_row0_col10" class="data row0 col10" >0.00</td>
#       <td id="T_0daf8_row0_col11" class="data row0 col11" >-0.03</td>
#       <td id="T_0daf8_row0_col12" class="data row0 col12" >-0.03</td>
#       <td id="T_0daf8_row0_col13" class="data row0 col13" >0.01</td>
#       <td id="T_0daf8_row0_col14" class="data row0 col14" >0.03</td>
#       <td id="T_0daf8_row0_col15" class="data row0 col15" >-0.02</td>
#       <td id="T_0daf8_row0_col16" class="data row0 col16" >-0.03</td>
#       <td id="T_0daf8_row0_col17" class="data row0 col17" >0.04</td>
#     </tr>
#     <tr>
#       <th id="T_0daf8_level0_row1" class="row_heading level0 row1" >LIME</th>
#       <td id="T_0daf8_row1_col0" class="data row1 col0" >0.13</td>
#       <td id="T_0daf8_row1_col1" class="data row1 col1" >0.04</td>
#       <td id="T_0daf8_row1_col2" class="data row1 col2" >0.19</td>
#       <td id="T_0daf8_row1_col3" class="data row1 col3" >0.09</td>
#       <td id="T_0daf8_row1_col4" class="data row1 col4" >-0.04</td>
#       <td id="T_0daf8_row1_col5" class="data row1 col5" >0.05</td>
#       <td id="T_0daf8_row1_col6" class="data row1 col6" >0.06</td>
#       <td id="T_0daf8_row1_col7" class="data row1 col7" >-0.05</td>
#       <td id="T_0daf8_row1_col8" class="data row1 col8" >-0.06</td>
#       <td id="T_0daf8_row1_col9" class="data row1 col9" >-0.03</td>
#       <td id="T_0daf8_row1_col10" class="data row1 col10" >0.03</td>
#       <td id="T_0daf8_row1_col11" class="data row1 col11" >-0.06</td>
#       <td id="T_0daf8_row1_col12" class="data row1 col12" >-0.02</td>
#       <td id="T_0daf8_row1_col13" class="data row1 col13" >-0.00</td>
#       <td id="T_0daf8_row1_col14" class="data row1 col14" >0.02</td>
#       <td id="T_0daf8_row1_col15" class="data row1 col15" >-0.01</t
# <style type="text/css">
# #T_f20f7_row0_col0 {
#   background-color: #e48990;
#   color: #f1f1f1;
#   background-color: #993499;
#   color: #f1f1f1;
# }
# #T_f20f7_row0_col1 {
#   background-color: #e9edf0;
#   color: #000000;
#   background-color: #b773b7;
#   color: #f1f1f1;
# }
# #T_f20f7_row0_col2 {
#   background-color: #e6959b;
#   color: #f1f1f1;
#   background-color: #9c3b9c;
#   color: #f1f1f1;
# }
# #T_f20f7_row1_col0 {
#   background-color: #e79a9f;
#   color: #000000;
#   background-color: #9e3e9e;
#   color: #f1f1f1;
# }
# #T_f20f7_row1_col1 {
#   background-color: #eff0f2;
#   color: #000000;
#   background-color: #b976b9;
#   color: #f1f1f1;
# }
# #T_f20f7_row1_col2 {
#   background-color: #e9aeb2;
#   color: #000000;
#   background-color: #a44ba4;
#   color: #f1f1f1;
# }
# #T_f20f7_row2_col0 {
#   background-color: #f1e7e7;
#   color: #000000;
#   background-color: #b671b6;
#   color: #f1f1f1;
# }
# #T_f20f7_row2_col1, #T_f20f7_row4_col1 {
#   background-color: #edc7ca;
#   color: #000000;
#   background-color: #c794c7;
#   color: #f1f1f1;
# }
# #T_f20f7_row2_col2 {
#   background-color: #ebeef0;
#   color: #000000;
#   background-color: #bb7cbb;
#   color: #f1f1f1;
# }
# #T_f20f7_row3_col0 {
#   background-color: #eed1d3;
#   color: #000000;
#   background-color: #af63af;
#   color: #f1f1f1;
# }
# #T_f20f7_row3_col1 {
#   background-color: #f1e5e6;
#   color: #000000;
#   background-color: #bd80bd;
#   color: #f1f1f1;
# }
# #T_f20f7_row3_col2 {
#   background-color: #edeff1;
#   color: #000000;
#   background-color: #bb7abb;
#   color: #f1f1f1;
# }
# #T_f20f7_row4_col0 {
#   background-color: #eed0d2;
#   color: #000000;
#   background-color: #af62af;
#   color: #f1f1f1;
# }
# #T_f20f7_row4_col2, #T_f20f7_row5_col2 {
#   background-color: #efd4d6;
#   color: #000000;
#   background-color: #b065b0;
#   color: #f1f1f1;
# }
# #T_f20f7_row5_col0 {
#   background-color: #ebbbbe;
#   color: #000000;
#   background-color: #a854a8;
#   color: #f1f1f1;
# }
# #T_f20f7_row5_col1 {
#   background-color: #eceef1;
#   color: #000000;
#   background-color: #b875b8;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f20f7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f20f7_level0_col0" class="col_heading level0 col0" >aopc_compr</th>
#       <th id="T_f20f7_level0_col1" class="col_heading level0 col1" >aopc_suff</th>
#       <th id="T_f20f7_level0_col2" class="col_heading level0 col2" >taucorr_loo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f20f7_level0_row0" class="row_heading level0 row0" >Partition SHAP</th>
#       <td id="T_f20f7_row0_col0" class="data row0 col0" >0.57</td>
#       <td id="T_f20f7_row0_col1" class="data row0 col1" >-0.04</td>
#       <td id="T_f20f7_row0_col2" class="data row0 col2" >0.50</td>
#     </tr>
#     <tr>
#       <th id="T_f20f7_level0_row1" class="row_heading level0 row1" >LIME</th>
#       <td id="T_f20f7_row1_col0" class="data row1 col0" >0.48</td>
#       <td id="T_f20f7_row1_col1" class="data row1 col1" >-0.01</td>
#       <td id="T_f20f7_row1_col2" class="data row1 col2" >0.37</td>
#     </tr>
#     <tr>
#       <th id="T_f20f7_level0_row2" class="row_heading level0 row2" >Gradient</th>
#       <td id="T_f20f7_row2_col0" class="data row2 col0" >0.06</td>
#       <td id="T_f20f7_row2_col1" class="data row2 col1" >0.23</td>
#       <td id="T_f20f7_row2_col2" class="data row2 col2" >-0.03</td>
#     </tr>
#     <tr>
#       <th id="T_f20f7_level0_row3" class="row_heading level0 row3" >Gradient (x Input)</th>
#       <td id="T_f20f7_row3_col0" class="data row3 col0" >0.17</td>
#       <td id="T_f20f7_row3_col1" class="data row3 col1" >0.07</td>
#       <td id="T_f20f7_row3_col2" class="data row3 col2" >-0.02</td>
#     </tr>
#     <tr>
#       <th id="T_f20f7_level0_row4" class="row_heading level0 row4" >Integrated Gradient</th>
#       <td id="T_f20f7_row4_col0" class="data row4 col0" >0.18</td>
#       <td id="T_f20f7_row4_col1" class="data row4 col1" >0.23</td>
#       <td id="T_f20f7_row4_col2" class="data row4 col2" >0.16</td>
#     </tr>
#     <tr>
#       <th id="T_f20f7_level0_row5" class="row_heading level0 row5" >Integrated Gradient (x Input)</th>
#       <td id="T_f20f7_row5_col0" class="data row5 col0" >0.30</td>
#       <td id="T_f20f7_row5_col1" class="data row5 col1" >-0.03</td>
#       <td id="T_f20f7_row5_col2" class="data row5 col2" >0.16</td>
#     </tr>
#   </tbody>
# </table>
# False Negative:
# Explainer:   0%|          | 0/6 [00:00<?, ?it/s]
# Explanation eval:   0%|          | 0/6 [00:00<?, ?it/s]
# Sentence: Es literalmente romantización de relaciones abusivas pero ahora en live action🤪🤪🤩🤩
# Class: 0
# <style type="text/css">
# #T_f2e06_row0_col0, #T_f2e06_row0_col9, #T_f2e06_row1_col12, #T_f2e06_row2_col7, #T_f2e06_row5_col4, #T_f2e06_row5_col9 {
#   background-color: #f1e4e5;
#   color: #000000;
# }
# #T_f2e06_row0_col1 {
#   background-color: #e1e7ec;
#   color: #000000;
# }
# #T_f2e06_row0_col2 {
#   background-color: #e4e9ed;
#   color: #000000;
# }
# #T_f2e06_row0_col3, #T_f2e06_row1_col10, #T_f2e06_row5_col3, #T_f2e06_row5_col8, #T_f2e06_row5_col11 {
#   background-color: #eff0f2;
#   color: #000000;
# }
# #T_f2e06_row0_col4, #T_f2e06_row3_col6, #T_f2e06_row5_col10 {
#   background-color: #f2f1f1;
#   color: #000000;
# }
# #T_f2e06_row0_col5, #T_f2e06_row2_col11 {
#   background-color: #f1e5e6;
#   color: #000000;
# }
# #T_f2e06_row0_col6 {
#   background-color: #c4d4e0;
#   color: #000000;
# }
# #T_f2e06_row0_col7, #T_f2e06_row5_col1, #T_f2e06_row5_col2 {
#   background-color: #dce3ea;
#   color: #000000;
# }
# #T_f2e06_row0_col8, #T_f2e06_row0_col12, #T_f2e06_row1_col4, #T_f2e06_row3_col3, #T_f2e06_row4_col5 {
#   background-color: #f2ebeb;
#   color: #000000;
# }
# #T_f2e06_row0_col10, #T_f2e06_row4_col12 {
#   background-color: #edeff1;
#   color: #000000;
# }
# #T_f2e06_row0_col11, #T_f2e06_row3_col2 {
#   background-color: #efd7d9;
#   color: #000000;
# }
# #T_f2e06_row1_col0 {
#   background-color: #f0e3e3;
#   color: #000000;
# }
# #T_f2e06_row1_col1, #T_f2e06_row4_col10 {
#   background-color: #dae3e9;
#   color: #000000;
# }
# #T_f2e06_row1_col2 {
#   background-color: #e0e6eb;
#   color: #000000;
# }
# #T_f2e06_row1_col3, #T_f2e06_row1_col8, #T_f2e06_row3_col0, #T_f2e06_row3_col4, #T_f2e06_row3_col10, #T_f2e06_row4_col1, #T_f2e06_row4_col9 {
#   background-color: #f1f1f2;
#   color: #000000;
# }
# #T_f2e06_row1_col5, #T_f2e06_row2_col12, #T_f2e06_row5_col0 {
#   background-color: #efdbdd;
#   color: #000000;
# }
# #T_f2e06_row1_col6 {
#   background-color: #bfd0dd;
#   color: #000000;
# }
# #T_f2e06_row1_col7 {
#   background-color: #e9edf0;
#   color: #000000;
# }
# #T_f2e06_row1_col9 {
#   background-color: #f2eded;
#   color: #000000;
# }
# #T_f2e06_row1_col11, #T_f2e06_row4_col2 {
#   background-color: #f0e1e2;
#   color: #000000;
# }
# #T_f2e06_row2_col0, #T_f2e06_row2_col4, #T_f2e06_row2_col8, #T_f2e06_row2_col9, #T_f2e06_row2_col10, #T_f2e06_row3_col12 {
#   background-color: #f2efef;
#   color: #000000;
# }
# #T_f2e06_row2_col1, #T_f2e06_row3_col11 {
#   background-color: #f1e7e7;
#   color: #000000;
# }
# #T_f2e06_row2_col2 {
#   background-color: #f0ddde;
#   color: #000000;
# }
# #T_f2e06_row2_col3 {
#   background-color: #f0e0e1;
#   color: #000000;
# }
# #T_f2e06_row2_col5 {
#   background-color: #eecdcf;
#   color: #000000;
# }
# #T_f2e06_row2_col6 {
#   background-color: #efd4d6;
#   color: #000000;
# }
# #T_f2e06_row3_col1 {
#   background-color: #eceef1;
#   color: #000000;
# }
# #T_f2e06_row3_col5 {
#   background-color: #9bb8ce;
#   color: #000000;
# }
# #T_f2e06_row3_col7 {
#   background-color: #d5dfe7;
#   color: #000000;
# }
# #T_f2e06_row3_col8 {
#   background-color: #f2eeee;
#   color: #000000;
# }
# #T_f2e06_row3_col9, #T_f2e06_row4_col6, #T_f2e06_row4_col8 {
#   background-color: #ebeef0;
#   color: #000000;
# }
# #T_f2e06_row4_col0 {
#   background-color: #f1eaea;
#   color: #000000;
# }
# #T_f2e06_row4_col3 {
#   background-color: #c7d6e1;
#   color: #000000;
# }
# #T_f2e06_row4_col4, #T_f2e06_row5_col5 {
#   background-color: #e7ebee;
#   color: #000000;
# }
# #T_f2e06_row4_col7, #T_f2e06_row5_col7 {
#   background-color: #d9e2e9;
#   color: #000000;
# }
# #T_f2e06_row4_col11 {
#   background-color: #e2e8ed;
#   color: #000000;
# }
# #T_f2e06_row5_col6 {
#   background-color: #dee5eb;
#   color: #000000;
# }
# #T_f2e06_row5_col12 {
#   background-color: #d8e1e8;
#   color: #000000;
# }
# </style>
# <table id="T_f2e06">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Token</th>
#       <th id="T_f2e06_level0_col0" class="col_heading level0 col0" >▁es</th>
#       <th id="T_f2e06_level0_col1" class="col_heading level0 col1" >▁literalmente</th>
#       <th id="T_f2e06_level0_col2" class="col_heading level0 col2" >▁roman</th>
#       <th id="T_f2e06_level0_col3" class="col_heading level0 col3" >tizacion</th>
#       <th id="T_f2e06_level0_col4" class="col_heading level0 col4" >▁de</th>
#       <th id="T_f2e06_level0_col5" class="col_heading level0 col5" >▁relaciones</th>
#       <th id="T_f2e06_level0_col6" class="col_heading level0 col6" >▁abus</th>
#       <th id="T_f2e06_level0_col7" class="col_heading level0 col7" >ivas</th>
#       <th id="T_f2e06_level0_col8" class="col_heading level0 col8" >▁pero</th>
#       <th id="T_f2e06_level0_col9" class="col_heading level0 col9" >▁ahora</th>
#       <th id="T_f2e06_level0_col10" class="col_heading level0 col10" >▁en</th>
#       <th id="T_f2e06_level0_col11" class="col_heading level0 col11" >▁live</th>
#       <th id="T_f2e06_level0_col12" class="col_heading level0 col12" >▁action</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2e06_level0_row0" class="row_heading level0 row0" >Partition SHAP</th>
#       <td id="T_f2e06_row0_col0" class="data row0 col0" >0.07</td>
#       <td id="T_f2e06_row0_col1" class="data row0 col1" >-0.09</td>
#       <td id="T_f2e06_row0_col2" class="data row0 col2" >-0.07</td>
#       <td id="T_f2e06_row0_col3" class="data row0 col3" >-0.01</td>
#       <td id="T_f2e06_row0_col4" class="data row0 col4" >0.00</td>
#       <td id="T_f2e06_row0_col5" class="data row0 col5" >0.07</td>
#       <td id="T_f2e06_row0_col6" class="data row0 col6" >-0.25</td>
#       <td id="T_f2e06_row0_col7" class="data row0 col7" >-0.12</td>
#       <td id="T_f2e06_row0_col8" class="data row0 col8" >0.04</td>
#       <td id="T_f2e06_row0_col9" class="data row0 col9" >0.08</td>
#       <td id="T_f2e06_row0_col10" class="data row0 col10" >-0.02</td>
#       <td id="T_f2e06_row0_col11" class="data row0 col11" >0.14</td>
#       <td id="T_f2e06_row0_col12" class="data row0 col12" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_f2e06_level0_row1" class="row_heading level0 row1" >LIME</th>
#       <td id="T_f2e06_row1_col0" class="data row1 col0" >0.08</td>
#       <td id="T_f2e06_row1_col1" class="data row1 col1" >-0.13</td>
#       <td id="T_f2e06_row1_col2" class="data row1 col2" >-0.10</td>
#       <td id="T_f2e06_row1_col3" class="data row1 col3" >-0.01</td>
#       <td id="T_f2e06_row1_col4" class="data row1 col4" >0.03</td>
#       <td id="T_f2e06_row1_col5" class="data row1 col5" >0.12</td>
#       <td id="T_f2e06_row1_col6" class="data row1 col6" >-0.28</td>
#       <td id="T_f2e06_row1_col7" class="data row1 col7" >-0.05</td>
#       <td id="T_f2e06_row1_col8" class="data row1 col8" >-0.00</td>
#       <td id="T_f2e06_row1_col9" class="data row1 col9" >0.03</td>
#       <td id="T_f2e06_row1_col10" class="data row1 col10" >-0.01</td>
#       <td id="T_f2e06_row1_col11" class="data row1 col11" >0.09</td>
#       <td id="T_f2e06_row1_col12" class="data row1 col12" >0.07</td>
#     </tr>
#     <tr>
#       <th id="T_f2e06_level0_row2" class="row_heading level0 row2" >Gradient</th>
#       <td id="T_f2e06_row2_col0" class="data row2 col0" >0.01</td>
#       <td id="T_f2e06_row2_col1" class="data row2 col1" >0.06</td>
#       <td id="T_f2e06_row2_col2" class="data row2 col2" >0.11</td>
#       <td id="T_f2e06_row2_col3" class="data row2 col3" >0.10</td>
#       <td id="T_f2e06_row2_col4" class="data row2 col4" >0.01</td>
#       <td id="T_f2e06_row2_col5" class="data row2 col5" >0.20</td>
#       <td id="T_f2e06_row2_col6" class="data row2 col6" >0.16</td>
#       <td id="T_f2e06_row2_col7" class="data row2 col7" >0.08</td>
#       <td id="T_f2e06_row2_col8" class="data row2 col8" >0.01</td>
#       <td id="T_f2e06_row2_col9" class="data row2 col9" >0.02</td>
#       <td id="T_f2e06_row2_col10" class="data row2 col10" >0.01</td>
#       <td id="T_f2e06_row2_col11" class="data row2 col11" >0.07</td>
#       <td id="T_f2e06_row2_col12" class="data row2 col12" >0.12</td>
#     </tr>
#     <tr>
#       <th id="T_f2e06_level0_row3" class="row_heading level0 row3" >Gradient (x Input)</th>
#       <td id="T_f2e06_row3_col0" class="data row3 col0" >-0.00</td>
#       <td id="T_f2e06_row3_col1" class="data row3 col1" >-0.03</td>
#       <td id="T_f2e06_row3_col2" class="data row3 col2" >0.15</td>
#       <td id="T_f2e06_row3_col3" class="data row3 col3" >0.03</td>
# <style type="text/css">
# #T_1c989_row0_col0 {
#   background-color: #e59097;
#   color: #f1f1f1;
#   background-color: #9b389b;
#   color: #f1f1f1;
# }
# #T_1c989_row0_col1 {
#   background-color: #dce3ea;
#   color: #000000;
#   background-color: #b269b2;
#   color: #f1f1f1;
# }
# #T_1c989_row0_col2 {
#   background-color: #e48990;
#   color: #f1f1f1;
#   background-color: #993499;
#   color: #f1f1f1;
# }
# #T_1c989_row1_col0 {
#   background-color: #e4888f;
#   color: #f1f1f1;
#   background-color: #983398;
#   color: #f1f1f1;
# }
# #T_1c989_row1_col1, #T_1c989_row4_col1 {
#   background-color: #e4e9ed;
#   color: #000000;
#   background-color: #b56fb5;
#   color: #f1f1f1;
# }
# #T_1c989_row1_col2 {
#   background-color: #e38188;
#   color: #f1f1f1;
#   background-color: #962e96;
#   color: #f1f1f1;
# }
# #T_1c989_row2_col0 {
#   background-color: #eff0f2;
#   color: #000000;
#   background-color: #ba79ba;
#   color: #f1f1f1;
# }
# #T_1c989_row2_col1 {
#   background-color: #edccce;
#   color: #000000;
#   background-color: #c591c5;
#   color: #f1f1f1;
# }
# #T_1c989_row2_col2 {
#   background-color: #dee5eb;
#   color: #000000;
#   background-color: #bf85bf;
#   color: #f1f1f1;
# }
# #T_1c989_row3_col0 {
#   background-color: #eecfd1;
#   color: #000000;
#   background-color: #ae61ae;
#   color: #f1f1f1;
# }
# #T_1c989_row3_col1 {
#   background-color: #f2eeee;
#   color: #000000;
#   background-color: #bb7abb;
#   color: #f1f1f1;
# }
# #T_1c989_row3_col2 {
#   background-color: #e4e9ed;
#   color: #000000;
#   background-color: #be81be;
#   color: #f1f1f1;
# }
# #T_1c989_row4_col0 {
#   background-color: #eecdcf;
#   color: #000000;
#   background-color: #ae60ae;
#   color: #f1f1f1;
# }
# #T_1c989_row4_col2 {
#   background-color: #efd6d7;
#   color: #000000;
#   background-color: #b166b1;
#   color: #f1f1f1;
# }
# #T_1c989_row5_col0 {
#   background-color: #f0e1e2;
#   color: #000000;
#   background-color: #b46db4;
#   color: #f1f1f1;
# }
# #T_1c989_row5_col1 {
#   background-color: #f2f1f1;
#   color: #000000;
#   background-color: #ba78ba;
#   color: #f1f1f1;
# }
# #T_1c989_row5_col2 {
#   background-color: #edc7ca;
#   color: #000000;
#   background-color: #ac5cac;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1c989">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1c989_level0_col0" class="col_heading level0 col0" >aopc_compr</th>
#       <th id="T_1c989_level0_col1" class="col_heading level0 col1" >aopc_suff</th>
#       <th id="T_1c989_level0_col2" class="col_heading level0 col2" >taucorr_loo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1c989_level0_row0" class="row_heading level0 row0" >Partition SHAP</th>
#       <td id="T_1c989_row0_col0" class="data row0 col0" >0.53</td>
#       <td id="T_1c989_row0_col1" class="data row0 col1" >-0.12</td>
#       <td id="T_1c989_row0_col2" class="data row0 col2" >0.56</td>
#     </tr>
#     <tr>
#       <th id="T_1c989_level0_row1" class="row_heading level0 row1" >LIME</th>
#       <td id="T_1c989_row1_col0" class="data row1 col0" >0.58</td>
#       <td id="T_1c989_row1_col1" class="data row1 col1" >-0.08</td>
#       <td id="T_1c989_row1_col2" class="data row1 col2" >0.62</td>
#     </tr>
#     <tr>
#       <th id="T_1c989_level0_row2" class="row_heading level0 row2" >Gradient</th>
#       <td id="T_1c989_row2_col0" class="data row2 col0" >-0.01</td>
#       <td id="T_1c989_row2_col1" class="data row2 col1" >0.21</td>
#       <td id="T_1c989_row2_col2" class="data row2 col2" >-0.10</td>
#     </tr>
#     <tr>
#       <th id="T_1c989_level0_row3" class="row_heading level0 row3" >Gradient (x Input)</th>
#       <td id="T_1c989_row3_col0" class="data row3 col0" >0.19</td>
#       <td id="T_1c989_row3_col1" class="data row3 col1" >0.02</td>
#       <td id="T_1c989_row3_col2" class="data row3 col2" >-0.08</td>
#     </tr>
#     <tr>
#       <th id="T_1c989_level0_row4" class="row_heading level0 row4" >Integrated Gradient</th>
#       <td id="T_1c989_row4_col0" class="data row4 col0" >0.20</td>
#       <td id="T_1c989_row4_col1" class="data row4 col1" >-0.07</td>
#       <td id="T_1c989_row4_col2" class="data row4 col2" >0.15</td>
#     </tr>
#     <tr>
#       <th id="T_1c989_level0_row5" class="row_heading level0 row5" >Integrated Gradient (x Input)</th>
#       <td id="T_1c989_row5_col0" class="data row5 col0" >0.09</td>
#       <td id="T_1c989_row5_col1" class="data row5 col1" >0.00</td>
#       <td id="T_1c989_row5_col2" class="data row5 col2" >0.23</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # DO IT IN ENGLISH

# %%
# COMPLETE
