# %% [markdown]
# # Lab1_S3 examples

# %%
#Installing Gensim library
# !pip install gensim
# !pip install nltk

# %% [markdown]
# ## Load the corpus

# %%
import pandas as pd

# %%
path = "EXIST2024_EN_examples.csv"
df = pd.read_csv(path, sep="\t")
df
# Out:
#           id                                               text label  size
# 0     200002  Writing a uni essay in my local pub with a cof...   YES   255
# 1     200003  @UniversalORL it is 2021 not 1921. I dont appr...   YES   191
# 2     200006  According to a customer I have plenty of time ...   YES   183
# 3     200007  So only 'blokes' drink beer? Sorry, but if you...   YES   197
# 4     200008  New to the shelves this week - looking forward...    NO   172
# ...      ...                                                ...   ...   ...
# 2847  203256  idk why y’all bitches think having half your a...   YES   143
# 2848  203257  This has been a part of an experiment with @Wo...   YES   278
# 2849  203258  "Take me already" "Not yet. You gotta be ready...   YES   264
# 2850  203259  @clintneedcoffee why do you look like a whore?...   YES    74
# 2851  203260  ik when mandy says “you look like a whore” i l...   YES    62
#
# [2852 rows x 4 columns]

# %%
# OR USING Google colab
#from google.colab import drive
#drive.mount('/content/drive')
#path = "/content/drive/MyDrive/LNR/LNR2025/Lab1/EXIST2024_EN_examples.csv"
#df = pd.read_csv(path, sep="\t")
#df

# %% [markdown]
# ###EXAMPLE 1: Listing the pre-trained word-embeddings in Gensim

# %%
#Listing the pretained embeddings available on Gensim
import gensim.downloader as api
info = api.info()
for item in info["models"].items():
   print (item)
# Out:
# ('fasttext-wiki-news-subwords-300', {'num_records': 999999, 'file_size': 1005007116, 'base_dataset': 'Wikipedia 2017, UMBC webbase corpus and statmt.org news dataset (16B tokens)', 'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/fasttext-wiki-news-subwords-300/__init__.py', 'license': 'https://creativecommons.org/licenses/by-sa/3.0/', 'parameters': {'dimension': 300}, 'description': '1 million word vectors trained on Wikipedia 2017, UMBC webbase corpus and statmt.org news dataset (16B tokens).', 'read_more': ['https://fasttext.cc/docs/en/english-vectors.html', 'https://arxiv.org/abs/1712.09405', 'https://arxiv.org/abs/1607.01759'], 'checksum': 'de2bb3a20c46ce65c9c131e1ad9a77af', 'file_name': 'fasttext-wiki-news-subwords-300.gz', 'parts': 1})
# ...

# %% [markdown]
# ###EXAMPLE 2: Loading pre-trained word embeddings vectors

# %%
#Downloading the pre-trained word embedding matrix generated by the Word2Vec method trained on Google News (about 100 billion words)
model = api.load("word2vec-google-news-300")
vec = model.get_vector("woman")
print(vec)
# Out:
# [ 2.43164062e-01 -7.71484375e-02 -1.03027344e-01 -1.07421875e-01
#   1.18164062e-01 -1.07421875e-01 -1.14257812e-01  2.56347656e-02
#   1.11816406e-01  4.85839844e-02 -9.71679688e-02 -3.43750000e-01
#  -6.29882812e-02 -1.25000000e-01 -2.70996094e-02  9.42382812e-02
#  -1.87500000e-01 -5.34667969e-02  6.25000000e-02 -3.05175781e-02
#  -2.90527344e-02 -4.80957031e-02 -5.51757812e-02 -4.08203125e-01
#   1.01318359e-02 -2.32421875e-01 -1.70898438e-01  2.63671875e-01
#   3.49609375e-01 -2.11914062e-01  1.43554688e-01 -6.22558594e-03
#  -2.25585938e-01 -1.05468750e-01 -1.16210938e-01  1.23046875e-01
#   3.06640625e-01 -4.88281250e-02 -9.57031250e-02  1.99218750e-01
#  -1.57226562e-01 -2.80761719e-02  1.58203125e-01 -2.42919922e-02
#   1.29882812e-01 -8.98437500e-02 -7.61718750e-02  3.54003906e-02
#  -3.06396484e-02  1.52343750e-01  5.24902344e-02  1.60980225e-03
#   5.56640625e-02  3.95507812e-02 -7.71484375e-02 -7.12890625e-02
# ...

# %%
# Downloading the pre-trained word embedding vectors generated by the FastText method  trained on Wikipedia 2017, UMBC webbase corpus and statmt.org news datase
model = api.load("fasttext-wiki-news-subwords-300")
vec = model.get_vector("woman")
print(vec)

#Loading the pre-trained word embedding vectors created by the GloVE method trained on  Wikipedia 2014 + Gigaword 5
model = api.load("glove-wiki-gigaword-300")
vec = model.get_vector("woman")
print(vec)

# %% [markdown]
# ###EXAMPLE 3: Computing similarity between words based on the pre-trained vector representations

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
words = "man woman kitchen football".split()
#Obtain the vectors for each word
dv=[model.get_vector(word) for word in words]
sim= np.round(cosine_similarity(dv,dv), 3)
dn = pd.DataFrame(index=words, columns=words, data=sim)
dn
# Out:
#             man  woman  kitchen  football
# man       1.000  0.766    0.077     0.268
# woman     0.766  1.000    0.138     0.121
# kitchen   0.077  0.138    1.000     0.054
# football  0.268  0.121    0.054     1.000

# %% [markdown]
# ### Some examples of the semantic relations captures by the word embeddig models

# %%
model.most_similar(positive=["Sweden"], negative=[], topn=15, restrict_vocab=None, indexer=None)
# Out:
# [('Finland', 0.8084676265716553),
#  ('Norway', 0.7706172466278076),
#  ('Denmark', 0.7673707008361816),
#  ('Swedish', 0.7404001355171204),
#  ('Swedes', 0.7133285999298096),
#  ('Scandinavian', 0.6518087983131409),
#  ('Stena_Match_Cup', 0.6437665820121765),
#  ('Netherlands', 0.6401046514511108),
#  ('official_Lars_Emilsson', 0.6374117732048035),
#  ('Stockholm', 0.6336992383003235),
#  ('Latvia', 0.6308620572090149),
#  ('Switzerland', 0.6276935935020447),
#  ('Scandinavia', 0.6253065466880798),
#  ('Bjorkdal_Gold_Mine', 0.6242160797119141),
#  ('Linkoeping', 0.6231747269630432)]

# %%
model.most_similar(positive=["king", "woman"], negative=["man"], topn=15, restrict_vocab=None, indexer=None)
# Out:
# [('queen', 0.7118193507194519),
#  ('monarch', 0.6189674139022827),
#  ('princess', 0.5902431011199951),
#  ('crown_prince', 0.5499460697174072),
#  ('prince', 0.5377321839332581),
#  ('kings', 0.5236844420433044),
#  ('Queen_Consort', 0.5235945582389832),
#  ('queens', 0.5181134343147278),
#  ('sultan', 0.5098593831062317),
#  ('monarchy', 0.5087411999702454),
#  ('royal_palace', 0.5087166428565979),
#  ('throne', 0.5005807876586914),
#  ('royal', 0.493820458650589),
#  ('Princess_Sikhanyiso', 0.4936617612838745),
#  ('ruler', 0.4909275770187378)]

# %%
model.most_similar(positive=["Spain", "Rome"], negative=["Madrid"], topn=15, restrict_vocab=None, indexer=None)
# Out:
# [('Italy', 0.7004685997962952),
#  ('Sicily', 0.59268718957901),
#  ('Greece', 0.5306450724601746),
#  ('defeated_Andreas_Seppi', 0.4919793903827667),
#  ('Sardinia', 0.48941102623939514),
#  ("Valle_D'_Aosta", 0.48918789625167847),
#  ('Lorenzago_di_Cadore', 0.48693549633026123),
#  ('Malta', 0.48546910285949707),
#  ('Romania', 0.4842848777770996),
#  ('Paestum', 0.47937682271003723),
#  ("Francesco_D'_Aniello", 0.47917160391807556),
#  ('Berlioz_Harold', 0.4779238998889923),
#  ('France', 0.47591346502304077),
#  ('Bambino_Gesu_Hospital', 0.4755710959434509),
#  ('Salonika_Greece', 0.47398701310157776)]

# %% [markdown]
# ### EXAMPLE 4: Loading pre-trained word embedding (created by Word2Vec) from a local file

# %%
# Download pretrained word embedding vectors generated by Word2Vec trained on Google News 2013 dataset
# !wget http://vectors.nlpl.eu/repository/20/1.zip
#!wget http://vectors.nlpl.eu/repository/20/6.zip
# !unzip 1.zip
#!unzip 6.zip

from gensim.models.keyedvectors import KeyedVectors
#Loading the pretarianed word embedding vectors from a binary file format
wordvb = KeyedVectors.load_word2vec_format('model.bin',  binary=True, limit=None)

#Loading the pretarianed word embedding vectors from a text file format
wordvt = KeyedVectors.load_word2vec_format('model.txt',  binary=False, limit=None)

# %% [markdown]
# ### EXAMPLE 5: Loading pre-trained word embedding (created by FastText) from a local file

# %%
# Download pre-trained word embedding vectors generated by FastText trained on Common Crawl and Wikipedia, in binary format
#!wget https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.en.300.bin.gz
#from gensim.models.keyedvectors import KeyedVectors
#Loading the pre-trained word embedding vectors from a binary file format
#wordvb = KeyedVectors.load_word2vec_format('cc.en.300.bin.gz', binary=True, limit=None)

# Download pre-trained word embedding vectors generated by FastText trained on Common Crawl and Wikipedia, in text format
# !wget https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.en.300.vec.gz
#Loading the pre-trained word embedding vectors from a text file format
wordvt = KeyedVectors.load_word2vec_format('cc.en.300.vec.gz', binary=False, limit=None)

# %% [markdown]
# ### EXAMPLE 6: Loading pre-trained word embedding (created by Glove) from a local file

# %%
# Download the pre-trained word embedding vectors generated by GloVe trained on a Twitter corpus
# !wget https://nlp.stanford.edu/data/wordvecs/glove.twitter.27B.zip
# !unzip glove.twitter.27B.zip
# Out:
# --2025-02-22 17:27:51--  https://nlp.stanford.edu/data/wordvecs/glove.twitter.27B.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://downloads.cs.stanford.edu/nlp/data/wordvecs/glove.twitter.27B.zip [following]
# --2025-02-22 17:27:51--  https://downloads.cs.stanford.edu/nlp/data/wordvecs/glove.twitter.27B.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1520408741 (1.4G) [application/zip]
# Saving to: ‘glove.twitter.27B.zip’
#
# glove.twitter.27B.z 100%[===================>]   1.42G  1.94MB/s    in 5m 39s
#
# 2025-02-22 17:33:30 (4.28 MB/s) - ‘glove.twitter.27B.zip’ saved [1520408741/1520408741]
#
# ...

# %%
from gensim.models.keyedvectors import KeyedVectors
size=None
wordv = KeyedVectors.load_word2vec_format('glove.twitter.27B.200d.txt',  binary=False, no_header=True, limit=size)
# Out:
# WARNING:gensim.models.keyedvectors:duplicate word '<unk>' in word2vec file, ignoring all but first
# WARNING:gensim.models.keyedvectors:duplicate word '<unk>' in word2vec file, ignoring all but first

# %%
wordv.get_vector("doctors")
# Out:
# array([ 3.1757e-01, -5.7845e-01, -3.9579e-01,  2.8347e-01,  3.1561e-01,
#        -2.7203e-01,  4.9718e-01,  3.7040e-01,  5.2751e-01, -2.4206e-01,
#         1.0819e-01,  7.8633e-02, -8.6085e-01, -1.6325e-01,  7.0262e-01,
#        -8.0698e-01, -4.5228e-01,  6.0755e-01, -4.5933e-01, -6.6005e-01,
#         4.2281e-01, -3.3672e-01,  1.4251e-01,  3.1925e-02,  6.5474e-01,
#         1.2764e+00, -9.6147e-02,  8.6969e-03, -1.3257e-01, -1.2353e-01,
#         4.4061e-01, -5.9514e-01,  2.0260e-01,  4.1254e-01, -1.8691e-01,
#        -1.7350e-01, -3.4907e-01,  3.5320e-01,  7.1500e-01,  3.0949e-01,
#         9.0643e-01, -1.2438e-01,  2.8870e-01, -6.7590e-01,  1.1703e-01,
#         8.6316e-01,  1.5931e-01,  5.6584e-01,  5.5294e-01,  5.2991e-01,
#        -1.5568e-01,  2.1371e-01, -4.8201e-01, -7.3439e-02, -1.7253e-01,
#         4.0986e-01, -4.2577e-01,  3.2559e-01,  2.5333e-01, -9.2971e-02,
#        -1.7417e-01, -2.1238e-02,  1.6682e-01, -1.4533e-01,  1.4443e-01,
# ...

# %% [markdown]
# ### EXAMPLE 7: Loading pre-trained word embedding vectors in Spanish from a local file

# %%
# Download pre-trained word embedding vectors generated by FastText trained on Common Crawl and Wikipedia, in binary format for Spanish
#!wget https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.es.300.bin.gz
#from gensim.models.keyedvectors import KeyedVectors
#Loading the pre-trained word embedding vectors from a binary file format
#wordvb = KeyedVectors.load_word2vec_format('cc.es.300.bin.gz', binary=True, limit=None)

# %% [markdown]
# ###EXAMPLE 8: Learning word embeddings vector on a specific corpus

# %%
import nltk
nltk.download("punkt_tab")
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize

# Tokenize the corpus. Notice that the preprocessing and tokenization of the texts can be customized depending on the task.
tokenized_corpus = [word_tokenize(sentence.lower()) for sentence in df["text"].tolist()]
# Train the Word2Vec model
model = Word2Vec(sentences=tokenized_corpus, vector_size=100, window=5, min_count=1, workers=4)
# Get the word vector for a specific word
word_vector = model.wv["woman"]
# Most similar words to "example"
similar_words = model.wv.most_similar("woman")
print("Word vector for 'doctors':", word_vector)
print("Most similar words to 'doctors':", similar_words)
model.wv.save_word2vec_format("my-word-embedding-vectors-100d.txt", binary=False)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# Word vector for 'doctors': [-4.60996389e-01  6.57014489e-01  2.16854721e-01  1.43921807e-01
#   2.99997061e-01 -1.24132895e+00  3.83461535e-01  1.76292408e+00
#  -5.93351245e-01 -7.29108393e-01 -1.81596741e-01 -1.06581700e+00
#  -3.05227458e-01  2.59013623e-01  3.20336819e-01 -7.88807571e-01
#   5.93299866e-01 -7.02982843e-01 -3.35223973e-01 -1.66159546e+00
#   4.20017600e-01  3.60404313e-01  8.54148269e-01 -3.52247298e-01
#  -2.82803893e-01  2.43252981e-02 -5.56697667e-01 -3.88925552e-01
#  -7.11213887e-01  5.55989183e-02  3.89182746e-01 -2.83574760e-01
#   5.00123799e-01 -9.82756376e-01 -2.74456948e-01  1.07175434e+00
#   2.58109599e-01 -2.60949820e-01 -4.66166228e-01 -1.14532113e+00
#   1.57628432e-01 -7.01909900e-01 -5.48126996e-01  2.16419131e-01
#   4.20538366e-01 -3.83250386e-01 -3.82903278e-01 -3.02622408e-01
# ...

# %% [markdown]
# ###EXAMPLE9: Obtaining the representation of a text using word embedding vectors

# %%
#Obtaining the words or terms in the text. This time we considered a simple whitespace splitting.
#Notice that, after split the texts, the stopwords can be removed
#dim is the dimension of the word embedding vectors.
def get_sentence_rep(text, keyedvec, dim=300):
    words= text.lower().split()
    zero_vec=np.zeros(dim)
    avg_vec=np.zeros(dim)
    total_w=0
    for w in words:
        try:
            avg_vec+=keyedvec[w]
            total_w+=1
        except:
           print(f"The word {w} is not found in the embedding matrix")
    if total_w == 0:
        return zero_vec
    return avg_vec/total_w

text= "The theory of paint indicates feelings of isolation in society"
get_sentence_rep(text, wordv, dim=200)
# Out:
# array([ 1.10728079e-01, -2.41359975e-03,  8.04889992e-02,  1.11822981e-02,
#         1.91767388e-01,  3.35076098e-01,  2.28565097e-01, -3.53715699e-01,
#        -1.99007994e-01, -1.86432800e-01,  2.90411700e-01,  1.22699997e-01,
#        -1.03384201e+00, -5.28682053e-02, -1.62239797e-01,  1.69918618e-02,
#         7.34258968e-02, -1.46386501e-01, -1.61766499e-01,  1.77796399e-01,
#        -7.68188011e-02,  6.90893047e-02,  3.37609872e-03,  1.78887603e-01,
#         6.97899006e-02,  9.02345003e-01,  1.47917901e-01,  1.19611048e-01,
#        -6.53349996e-02,  3.85862952e-02,  1.16280795e-02, -2.90007303e-01,
#        -1.43445700e-01, -1.44891306e-01, -1.07311800e-01, -1.09994801e-01,
#         4.96960036e-02,  1.73614409e-01,  9.31910009e-02,  4.89425048e-02,
#         3.69661793e-01, -2.92963043e-02,  1.39141436e-01, -1.02758892e-01,
#         3.02879405e-01,  7.21744973e-02,  2.11248998e-02,  4.57060002e-03,
# ...
